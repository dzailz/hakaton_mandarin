# %% [markdown]
# #Условие и задача (свернуть и запустить весь код)

# %% [markdown]
#     Данные заемщика;Параметр;Комментарий
#     Идентификатор заявки;SkillFactory_Id;
#     Дата рождения;BirthDate;
#     Образование;education;
#     Тип занятости;employment status;
#     Стаж работы;Value;
#     Дата начала работы;JobStartDate;
#     Должность;Position;
#     Ежемесячный доход;MonthProfit;
#     Ежемесячный расход;MonthExpense;
#     Пол;Gender;Значения: 0 = М, 1 = Ж
#     Семейное положение;Family status;
#     Кол-во детей младше 18 лет;ChildCount;
#     СНИЛС;SNILS;Значения: 0 = не указан в анкете, 1 = указан
#     Параметры заказа;;
#     Сумма заказа;Loan_amount;
#     Срок кредита;Loan_term;
#     Категория товара;Goods_category;
#     Код магазина;Merch_code;
#     Решение банка А;BankA_decision;Значения: denied = отказ банка по заявке, success = одобрение банком заявки, error = банк вернул ошибку
#     Решение банка B;BankB_decision;Значения: denied = отказ банка по заявке, success = одобрение банком заявки, error = банк вернул ошибку
#     Решение банка C;BankC_decision;Значения: denied = отказ банка по заявке, success = одобрение банком заявки, error = банк вернул ошибку
#     Решение банка D;BankD_decision;Значения: denied = отказ банка по заявке, success = одобрение банком заявки, error = банк вернул ошибку
#     Решение банка E;BankE_decision;Значения: denied = отказ банка по заявке, success = одобрение банком заявки, error = банк вернул ошибку

# %% [markdown]
# https://docs.google.com/document/d/1BCt5JNeiWXYXAPVm1ofFx-D1IopwxISXgVwI4d1rgJs/edit

# %% [markdown]
# ## скачать и импортировать

# %%
# !wget https://www.dropbox.com/scl/fi/1dm9qq6ceyz7dqrob96ix/SF_Mandarin_dataset_ver3_csv.csv?rlkey=jkngphmwkoocingpxoga0uv2v&dl=0
# Out:
# --2023-12-02 05:44:09--  https://www.dropbox.com/scl/fi/1dm9qq6ceyz7dqrob96ix/SF_Mandarin_dataset_ver3_csv.csv?rlkey=jkngphmwkoocingpxoga0uv2v
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com/cd/0/inline/CIoHBYRUpTPyb3_osHAqrgOH_yvgmZLg8WGA0pexQ8R6AEwL2gjnPP26Jb_4B9gKWUzKnLl5r55gpoobLliaGJMH75lC6TGnLAhGL3SjJmPfMqpTfWNCWCvh_pBr5MPoe_Ruao9ZVjFJuaEhias3XNrt/file# [following]
# --2023-12-02 05:44:10--  https://uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com/cd/0/inline/CIoHBYRUpTPyb3_osHAqrgOH_yvgmZLg8WGA0pexQ8R6AEwL2gjnPP26Jb_4B9gKWUzKnLl5r55gpoobLliaGJMH75lC6TGnLAhGL3SjJmPfMqpTfWNCWCvh_pBr5MPoe_Ruao9ZVjFJuaEhias3XNrt/file
# Resolving uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com (uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com (uc394f3c02e7b171b8f9fdfec47f.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2263967 (2.2M) [text/plain]
# Saving to: ‘SF_Mandarin_dataset_ver3_csv.csv?rlkey=jkngphmwkoocingpxoga0uv2v’
#
# SF_Mandarin_dataset 100%[===================>]   2.16M  --.-KB/s    in 0.07s
#
# 2023-12-02 05:44:10 (30.4 MB/s) - ‘SF_Mandarin_dataset_ver3_csv.csv?rlkey=jkngphmwkoocingpxoga0uv2v’ saved [2263967/2263967]

# %%
import pandas as pd
import numpy as np
#для создания графиков
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

df = pd.read_csv('/content/SF_Mandarin_dataset_ver3_csv.csv?rlkey=jkngphmwkoocingpxoga0uv2v',sep=';')

# %%
df
# Out:
#       SkillFactory_Id                    BirthDate            education  \
# 0                 1.0  1988-07-21 00:00:00.0000000  Высшее - специалист
# 1                 2.0  1998-01-16 00:00:00.0000000  Высшее - специалист
# 2                 3.0  1972-10-02 00:00:00.0000000  Высшее - специалист
# 3                 4.0  1972-10-02 00:00:00.0000000  Высшее - специалист
# 4                 5.0  1972-10-02 00:00:00.0000000  Высшее - специалист
# ...               ...                          ...                  ...
# 8782              NaN                          NaN                  NaN
# 8783              NaN                          NaN                  NaN
# 8784              NaN                          NaN                  NaN
# 8785              NaN                          NaN                  NaN
# 8786              NaN                          NaN                  NaN
#
#                                employment status           Value  \
# 0     Работаю по найму полный рабочий день/служу      9 - 10 лет
# 1                               Собственное дело      1 - 2 года
# 2     Работаю по найму полный рабочий день/служу  10 и более лет
# 3     Работаю по найму полный рабочий день/служу  10 и более лет
# 4     Работаю по найму полный рабочий день/служу  10 и более лет
# ...                                          ...             ...
# 8782                                         NaN             NaN
# 8783                                         NaN             NaN
# 8784                                         NaN             NaN
# 8785                                         NaN             NaN
# 8786                                         NaN             NaN
#
#                      JobStartDate     Position  MonthProfit  MonthExpense  \
# 0     2013-09-01 00:00:00.0000000  начальник п     180000.0       90000.0
# 1     2022-12-01 00:00:00.0000000     директор     200000.0       60000.0
# 2     2005-12-01 00:00:00.0000000     ДИРЕКТОР     300000.0       45000.0
# 3     2005-12-01 00:00:00.0000000     ДИРЕКТОР     300000.0       45000.0
# 4     2005-12-01 00:00:00.0000000     ДИРЕКТОР     300000.0       45000.0
# ...                           ...          ...          ...           ...
# 8782                          NaN          NaN          NaN           NaN
# 8783                          NaN          NaN          NaN           NaN
# 8784                          NaN          NaN          NaN           NaN
# 8785                          NaN          NaN          NaN           NaN
# 8786                          NaN          NaN          NaN           NaN
#
#       Gender  ... SNILS  BankA_decision  BankB_decision BankC_decision  \
# 0        0.0  ...   0.0         success         success        success
# 1        0.0  ...   0.0         success          denied        success
# 2        1.0  ...   0.0          denied          denied        success
# 3        1.0  ...   0.0         success          denied        success
# 4        1.0  ...   0.0         success          denied        success
# ...      ...  ...   ...             ...             ...            ...
# 8782     NaN  ...   NaN             NaN             NaN            NaN
# 8783     NaN  ...   NaN             NaN             NaN            NaN
# 8784     NaN  ...   NaN             NaN             NaN            NaN
# 8785     NaN  ...   NaN             NaN             NaN            NaN
# 8786     NaN  ...   NaN             NaN             NaN            NaN
#
#      BankD_decision BankE_decision Merch_code Loan_amount  Loan_term  \
# 0           success         denied       77.0    137000.0       18.0
# 1            denied        success       27.0     33000.0        6.0
# 2           success        success       19.0    165000.0       24.0
# 3           success        success       34.0     67000.0       12.0
# 4           success        success       75.0     36000.0        6.0
# ...             ...            ...        ...         ...        ...
# 8782            NaN            NaN        NaN         NaN        NaN
# 8783            NaN            NaN        NaN         NaN        NaN
# 8784            NaN            NaN        NaN         NaN        NaN
# 8785            NaN            NaN        NaN         NaN        NaN
# 8786            NaN            NaN        NaN         NaN        NaN
#
#         Goods_category
# 0            Furniture
# 1              Fitness
# 2     Medical_services
# 3            Education
# 4            Furniture
# ...                ...
# 8782               NaN
# 8783               NaN
# 8784               NaN
# 8785               NaN
# 8786               NaN
#
# [8787 rows x 22 columns]

# %% [markdown]
# ## 1 . EDA

# %% [markdown]
# ### 1.0 перво знакомство (КАК под другому назвать)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8787 entries, 0 to 8786
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SkillFactory_Id    6603 non-null   float64
#  1   BirthDate          6603 non-null   object
#  2   education          6603 non-null   object
#  3   employment status  6603 non-null   object
#  4   Value              6523 non-null   object
#  5   JobStartDate       6494 non-null   object
#  6   Position           6494 non-null   object
#  7   MonthProfit        6603 non-null   float64
#  8   MonthExpense       6603 non-null   float64
#  9   Gender             6566 non-null   float64
#  10  Family status      6566 non-null   object
#  11  ChildCount         6566 non-null   float64
#  12  SNILS              6603 non-null   float64
#  13  BankA_decision     6603 non-null   object
#  14  BankB_decision     6603 non-null   object
#  15  BankC_decision     6603 non-null   object
#  16  BankD_decision     6603 non-null   object
#  17  BankE_decision     6603 non-null   object
#  18  Merch_code         6603 non-null   float64
#  19  Loan_amount        6603 non-null   float64
#  20  Loan_term          6603 non-null   float64
#  21  Goods_category     6603 non-null   object
# dtypes: float64(9), object(13)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#        SkillFactory_Id   MonthProfit   MonthExpense       Gender   ChildCount  \
# count      6603.000000  6.603000e+03    6603.000000  6566.000000  6566.000000
# mean       4388.192640  1.484528e+05   26234.063153     0.309625     0.097320
# std        2515.520596  7.742496e+04   22557.993167     0.462374     0.423026
# min           1.000000  5.000000e+01       0.000000     0.000000     0.000000
# 25%        2225.500000  1.000000e+05   15000.000000     0.000000     0.000000
# 50%        4431.000000  1.450000e+05   22500.000000     0.000000     0.000000
# 75%        6516.500000  1.900000e+05   31000.000000     1.000000     0.000000
# max        8787.000000  1.200000e+06  500000.000000     1.000000     5.000000
#
#              SNILS   Merch_code    Loan_amount    Loan_term
# count  6603.000000  6603.000000    6603.000000  6603.000000
# mean      0.350295    38.794184   76362.108133    12.117219
# std       0.477099    23.929860   50978.500496     5.996582
# min       0.000000     1.000000    4000.000000     6.000000
# 25%       0.000000    18.000000   35000.000000     6.000000
# 50%       0.000000    36.000000   68000.000000    12.000000
# 75%       1.000000    63.000000  101000.000000    18.000000
# max       1.000000    80.000000  200000.000000    24.000000

# %%
df.nunique().to_frame()#уникальные значения
# Out:
#                       0
# SkillFactory_Id    6603
# BirthDate          2628
# education            10
# employment status     7
# Value                13
# JobStartDate        288
# Position           1131
# MonthProfit         303
# MonthExpense        210
# Gender                2
# Family status         5
# ChildCount            6
# SNILS                 2
# BankA_decision        3
# BankB_decision        3
# BankC_decision        3
# BankD_decision        3
# BankE_decision        3
# Merch_code           70
# Loan_amount         197
# Loan_term             4
# Goods_category        7

# %%
df.isnull().sum()
# Out:
# SkillFactory_Id      2184
# BirthDate            2184
# education            2184
# employment status    2184
# Value                2264
# JobStartDate         2293
# Position             2293
# MonthProfit          2184
# MonthExpense         2184
# Gender               2221
# Family status        2221
# ChildCount           2221
# SNILS                2184
# BankA_decision       2184
# BankB_decision       2184
# BankC_decision       2184
# BankD_decision       2184
# BankE_decision       2184
# Merch_code           2184
# Loan_amount          2184
# Loan_term            2184
# Goods_category       2184
# dtype: int64

# %%
df.isnull().all(axis=1).sum() #2184 строка полностью пустые
# Out:
# 2184

# %%
df = df[df.SkillFactory_Id.isna() == False] #избавляюсь от полностью пустых строк

# %%
df.isnull().sum()
# Out:
# SkillFactory_Id        0
# BirthDate              0
# education              0
# employment status      0
# Value                 80
# JobStartDate         109
# Position             109
# MonthProfit            0
# MonthExpense           0
# Gender                37
# Family status         37
# ChildCount            37
# SNILS                  0
# BankA_decision         0
# BankB_decision         0
# BankC_decision         0
# BankD_decision         0
# BankE_decision         0
# Merch_code             0
# Loan_amount            0
# Loan_term              0
# Goods_category         0
# dtype: int64

# %% [markdown]
# ### 1.1 выделяю датасет без пропусков и преобразую колонки

# %%
df_drop = df.copy()

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-119-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
#КОД ВЛАДИМИРА

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])
df['JobStartDate'] = pd.to_datetime(df['JobStartDate'])
# Out:
# <ipython-input-121-726884e0ea53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BirthDate'] = pd.to_datetime(df['BirthDate'])
# <ipython-input-121-726884e0ea53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobStartDate'] = pd.to_datetime(df['JobStartDate'])

# %%
df['MonthProfit'] = df['MonthProfit'].astype('UInt64')
df['MonthExpense'] = df['MonthExpense'].astype('UInt64')
df['Loan_amount'] = df['Loan_amount'].astype('UInt64')
# Out:
# <ipython-input-122-853377163645>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthProfit'] = df['MonthProfit'].astype('UInt64')
# <ipython-input-122-853377163645>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthExpense'] = df['MonthExpense'].astype('UInt64')
# <ipython-input-122-853377163645>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_amount'] = df['Loan_amount'].astype('UInt64')

# %%
df['SNILS'] = df['SNILS'].round().astype('UInt8')
df['Gender'] = df['Gender'].round().astype('UInt8')
df['Merch_code'] = df['Merch_code'].astype('UInt8')
df['ChildCount'] = df['ChildCount'].astype('UInt8')
df['Loan_term'] = df['Loan_term'].astype('UInt8')
# Out:
# <ipython-input-123-3f0fce9db389>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SNILS'] = df['SNILS'].round().astype('UInt8')
# <ipython-input-123-3f0fce9db389>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].round().astype('UInt8')
# <ipython-input-123-3f0fce9db389>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Merch_code'] = df['Merch_code'].astype('UInt8')
# <ipython-input-123-3f0fce9db389>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ChildCount'] = df['ChildCount'].astype('UInt8')
# <ipython-input-123-3f0fce9db389>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_term'] = df['Loan_term'].astype('UInt8')

# %%
df['SNILS'] = df['SNILS'].round().astype('category')
df['Gender'] = df['Gender'].round().astype('category')
df['education'] = df['education'].astype('category')
# Out:
# <ipython-input-124-dd5706d7604a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SNILS'] = df['SNILS'].round().astype('category')
# <ipython-input-124-dd5706d7604a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].round().astype('category')
# <ipython-input-124-dd5706d7604a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['education'] = df['education'].astype('category')

# %%
#df['BankA_decision'] = df['BankA_decision'].astype('category') # У САМОГО ВЛАДИМИРА ПОСЛЕ АТКИХ ПРЕОБРАЗОВАНИЙ КОЛД НЕ РАБОАТЕТ
#df['BankB_decision'] = df['BankB_decision'].astype('category')
#df['BankC_decision'] = df['BankC_decision'].astype('category')
#df['BankD_decision'] = df['BankD_decision'].astype('category')
#df['BankE_decision'] = df['BankE_decision'].astype('category')
df['Family status'] = df['Family status'].astype('category')
df['Goods_category'] = df['Goods_category'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6464 entries, 0 to 6602
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SkillFactory_Id    6464 non-null   float64
#  1   BirthDate          6464 non-null   datetime64[ns]
#  2   education          6464 non-null   category
#  3   employment status  6464 non-null   object
#  4   Value              6464 non-null   object
#  5   JobStartDate       6464 non-null   datetime64[ns]
#  6   Position           6464 non-null   object
#  7   MonthProfit        6464 non-null   UInt64
#  8   MonthExpense       6464 non-null   UInt64
#  9   Gender             6464 non-null   category
#  10  Family status      6464 non-null   category
#  11  ChildCount         6464 non-null   UInt8
#  12  SNILS              6464 non-null   category
#  13  BankA_decision     6464 non-null   object
#  14  BankB_decision     6464 non-null   object
#  15  BankC_decision     6464 non-null   object
#  16  BankD_decision     6464 non-null   object
#  17  BankE_decision     6464 non-null   object
#  18  Merch_code         6464 non-null   UInt8
#  19  Loan_amount        6464 non-null   UInt64
#  20  Loan_term          6464 non-null   UInt8
#  21  Goods_category     6464 non-null   category
# dtypes: UInt64(3), UInt8(3), category(5), datetime64[ns](2), float64(1), object(8)
# memory usage: 847.0+ KB

# %%
df.describe()
# Out:
#        SkillFactory_Id    MonthProfit  MonthExpense  ChildCount  Merch_code  \
# count      6464.000000         6464.0        6464.0      6464.0      6464.0
# mean       4380.808323  149521.575959  25739.983137    0.090037   38.787593
# std        2518.767538   76000.700594  20301.771239    0.407951   23.895536
# min           1.000000           50.0           0.0         0.0         1.0
# 25%        2212.750000       100000.0       15000.0         0.0        18.0
# 50%        4409.500000       148000.0       22500.0         0.0        36.0
# 75%        6522.500000       190000.0       30000.0         0.0        63.0
# max        8787.000000      1200000.0      500000.0         5.0        80.0
#
#         Loan_amount  Loan_term
# count        6464.0     6464.0
# mean   76153.155941   12.09375
# std    50926.107415   5.989045
# min          4000.0        6.0
# 25%         35000.0        6.0
# 50%         67000.0       12.0
# 75%        100000.0       18.0
# max        200000.0       24.0

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(), annot=True, cmap="PRGn", cbar=False);
# Out:
# <ipython-input-128-c478e47a55e0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="PRGn", cbar=False);

# %% [markdown]
# ### 1.2 предполагаемые преобразования, графики распределения значений (датасет без пропусков)

# %%
df.columns
# Out:
# Index(['SkillFactory_Id', 'BirthDate', 'education', 'employment status',
#        'Value', 'JobStartDate', 'Position', 'MonthProfit', 'MonthExpense',
#        'Gender', 'Family status', 'ChildCount', 'SNILS', 'BankA_decision',
#        'BankB_decision', 'BankC_decision', 'BankD_decision', 'BankE_decision',
#        'Merch_code', 'Loan_amount', 'Loan_term', 'Goods_category'],
#       dtype='object')

# %%
df
# Out:
#       SkillFactory_Id  BirthDate            education  \
# 0                 1.0 1988-07-21  Высшее - специалист
# 1                 2.0 1998-01-16  Высшее - специалист
# 2                 3.0 1972-10-02  Высшее - специалист
# 3                 4.0 1972-10-02  Высшее - специалист
# 4                 5.0 1972-10-02  Высшее - специалист
# ...               ...        ...                  ...
# 6598           8780.0 1975-09-07  Высшее - специалист
# 6599           8782.0 1985-04-20  Высшее - специалист
# 6600           8783.0 1987-12-19  Высшее - специалист
# 6601           8786.0 2003-10-05  Неоконченное высшее
# 6602           8787.0 2003-10-05  Неоконченное высшее
#
#                                employment status           Value JobStartDate  \
# 0     Работаю по найму полный рабочий день/служу      9 - 10 лет   2013-09-01
# 1                               Собственное дело      1 - 2 года   2022-12-01
# 2     Работаю по найму полный рабочий день/служу  10 и более лет   2005-12-01
# 3     Работаю по найму полный рабочий день/служу  10 и более лет   2005-12-01
# 4     Работаю по найму полный рабочий день/служу  10 и более лет   2005-12-01
# ...                                          ...             ...          ...
# 6598  Работаю по найму полный рабочий день/служу  10 и более лет   2010-06-01
# 6599  Работаю по найму полный рабочий день/служу  10 и более лет   2020-01-01
# 6600                            Собственное дело  10 и более лет   2021-11-01
# 6601  Работаю по найму полный рабочий день/служу      1 - 2 года   2022-08-01
# 6602  Работаю по найму полный рабочий день/служу      1 - 2 года   2022-08-01
#
#                   Position  MonthProfit  MonthExpense Gender  ... SNILS  \
# 0              начальник п       180000         90000      0  ...     0
# 1                 директор       200000         60000      0  ...     0
# 2                 ДИРЕКТОР       300000         45000      1  ...     0
# 3                 ДИРЕКТОР       300000         45000      1  ...     0
# 4                 ДИРЕКТОР       300000         45000      1  ...     0
# ...                    ...          ...           ...    ...  ...   ...
# 6598  ГЕНЕРАЛЬНЫЙ ДИРЕКТОР       125000         15000      1  ...     0
# 6599           УПРАВЛЯЮЩИЙ       150000         14000      1  ...     0
# 6600  МЕНЕДЖЕР ПО ПРОДАЖАМ       130000         30000      0  ...     1
# 6601             продавец        150000         10000      1  ...     1
# 6602             продавец        150000         10000      1  ...     1
#
#       BankA_decision BankB_decision BankC_decision BankD_decision  \
# 0            success        success        success        success
# 1            success         denied        success         denied
# 2             denied         denied        success        success
# 3            success         denied        success        success
# 4            success         denied        success        success
# ...              ...            ...            ...            ...
# 6598         success        success        success        success
# 6599          denied        success        success        success
# 6600         success        success        success        success
# 6601         success        success        success        success
# 6602          denied        success        success        success
#
#      BankE_decision Merch_code Loan_amount  Loan_term    Goods_category
# 0            denied         77      137000         18         Furniture
# 1           success         27       33000          6           Fitness
# 2           success         19      165000         24  Medical_services
# 3           success         34       67000         12         Education
# 4           success         75       36000          6         Furniture
# ...             ...        ...         ...        ...               ...
# 6598        success         37        7000          6         Education
# 6599         denied         45       20000          6            Travel
# 6600        success         22       40000          6           Fitness
# 6601        success         74       23000          6         Furniture
# 6602        success         62       98000         12    Mobile_devices
#
# [6464 rows x 22 columns]

# %% [markdown]
# #### 1.2.1 Категориальные столбцы

# %% [markdown]
# ##### 1.2.1.1 Education(Образование)

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.education)
plt.title('Распределение значений "Образование"')
plt.show()

# %%
df.education.value_counts().to_frame()
# Out:
#                           education
# Высшее - специалист            5258
# Среднее профессиональное        443
# Неоконченное высшее             215
# Среднее                         194
# Бакалавр                        144
# Несколько высших                109
# Магистр                          71
# Неоконченное среднее             26
# MBA                               3
# Ученая степень                    1

# %%
df['BankA_decision']
# Out:
# 0       success
# 1       success
# 2        denied
# 3       success
# 4       success
#          ...
# 6598    success
# 6599     denied
# 6600    success
# 6601    success
# 6602     denied
# Name: BankA_decision, Length: 6464, dtype: object

# %%
plt.figure(figsize=(22, 12))
plt.hist(df[df['BankA_decision'] == 'success']['education'], alpha=0.5, label='success')
plt.hist(df[(df['BankA_decision'] == 'denied') |(df['BankA_decision'] == 'error' )]['education'], alpha=0.5, label='denied|error')
plt.title('Распределение "Образование" по "BankA_decision"')
plt.xlabel('Образование')
plt.ylabel('Частота')
plt.legend()
plt.show()

# %%
df['BankA_decision'].value_counts()
#bank_a_decision_counts[0]
# Out:
# success    4860
# denied     1535
# error        69
# Name: BankA_decision, dtype: int64

# %% [markdown]
# ##### 1.2.1.2 employment status(тип занятости)

# %%
plt.figure(figsize=(20, 6))
plt.hist(df['employment status'])
plt.title('Распределение значений "Тип занятости"')
plt.show()

# %%
df['employment status'].value_counts().to_frame()
# Out:
#                                             employment status
# Работаю по найму полный рабочий день/служу               4843
# Собственное дело                                         1516
# Работаю по найму неполный рабочий день                     61
# Декретный отпуск                                           19
# Пенсионер                                                  15
# Не работаю                                                  8
# Студент                                                     2

# %%
plt.figure(figsize=(22, 12))
plt.hist(df[df['BankA_decision'] == 'success']['employment status'], alpha=0.5, label='success')
plt.hist(df[(df['BankA_decision'] == 'denied') |(df['BankA_decision'] == 'error' )]['employment status'], alpha=0.5, label='denied|error')
plt.title('Распределение "Образование" по "BankA_decision"')
plt.xlabel('Образование')
plt.ylabel('Частота')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1.2.1.3 value(стаж работы)

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.Value)
plt.title('Распределение значений "Стаж работы"')
plt.show()

# %%
df.Value.value_counts().to_frame()
# Out:
#                    Value
# 10 и более лет      3605
# 3 - 4 года           521
# 2 - 3 года           498
# 4 - 5 лет            366
# 5 - 6 лет            289
# 1 - 2 года           269
# 6 - 7 лет            250
# 7 - 8 лет            225
# 8 - 9 лет            152
# 6 месяцев - 1 год    118
# 9 - 10 лет            88
# 4 - 6 месяцев         51
# менее 4 месяцев       32

# %% [markdown]
# ##### 1.2.1.4 Position(Должность)

# %%
#нерабочий вариант больше 15 минут крутится без толку
#! pip install pyspellchecker
#from spellchecker import SpellChecker
#spell = SpellChecker(language='ru')
# Создаем объект проверки правописания

# Исправляем опечатки в столбце
#df['Position'] = df['Position'].apply(lambda x: spell.correction(x))

# %%
df['Position'] = df['Position'].apply(lambda x: x.lower())
df['Position'] = df['Position'].str.replace(',', '')
df['Position'] = df['Position'].str.rstrip()#удаляем пробелы в конце строки
pd.DataFrame(df.Position.unique())#825 должностей, которые после нормальной обработки сильнее сократятся
# Out:
#                                    0
# 0                        начальник п
# 1                           директор
# 2                          строитель
# 3                           менеджер
# 4                        самозанятая
# ..                               ...
# 820  медицинский лабораторный техник
# 821                          управля
# 822                          уборщик
# 823                         фотограф
# 824                               км
#
# [825 rows x 1 columns]

# %% [markdown]
# ##### 1.2.1.5 Gender(Пол)

# %%
df.Gender = df.Gender.astype('int8')
plt.figure(figsize=(8, 6))
plt.hist(df.Gender)
plt.title('Распределение значений "Пол"')
plt.show()#женщин в 2 раза меньше обращается за кредитом

# %% [markdown]
# ##### 1.2.1.6 Family status(Семейный статус)

# %%
plt.figure(figsize=(15, 6))
plt.hist(df['Family status'])
plt.title('Распределение значений "Семейный статус"')
plt.show() #гражданский "брак" заменить на сожительство

# %% [markdown]
# ##### 1.2.1.7 ChildCount(Количество детей младше 18 лет)

# %%
plt.figure(figsize=(15, 6))
plt.hist(df.ChildCount)
plt.title('Распределение значений "Количество детей младше 18 лет"')
plt.show() #можно сделать категорию есть дети/бездетные #а ещё совместно с семейным статусом сделать родитель одиночка

# %%
df.ChildCount.value_counts().to_frame().T
# Out:
#                0    1    2   3  4  5
# ChildCount  6102  186  140  29  6  1

# %%
# Установка стиля для seaborn
sns.set(style="whitegrid")
# Создание столбчатой диаграммы сравнения 'Family status' с 'ChildCount'
plt.figure(figsize=(20, 6))
sns.barplot(x='Family status', y='ChildCount', data=df, palette='viridis', hue='Goods_category')
plt.title('Сравнение семейного статуса и количества детей')
plt.xlabel('Семейный статус')
plt.ylabel('Количество детей')
plt.show()

# %%
# Создание столбчатой диаграммы сравнения 'MonthProfit' и 'MonthExpense'
plt.figure(figsize=(20, 6))
sns.barplot(x='Family status', y='MonthProfit', data=df, color='skyblue', label='Доход за месяц', ci=None)
sns.barplot(x='Family status', y='MonthExpense', data=df, color='orange', label='Расход за месяц', ci=None)
plt.title('Сравнение доходов и расходов по семейному статусу')
plt.xlabel('Семейный статус')
plt.ylabel('Сумма')
plt.legend()
plt.show()
# Out:
# <ipython-input-148-64e40c2d8626>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Family status', y='MonthProfit', data=df, color='skyblue', label='Доход за месяц', ci=None)
# <ipython-input-148-64e40c2d8626>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Family status', y='MonthExpense', data=df, color='orange', label='Расход за месяц', ci=None)

# %% [markdown]
# ##### 1.2.1.8 SNILS(Наличие СНИЛС)

# %%
plt.figure(figsize=(7, 6))
plt.hist(df.SNILS)
plt.title('Распределение значений "наличие СНИЛС"')
plt.show()

# %% [markdown]
# ##### 1.2.1.9 Merch_code (код магазина)

# %%
plt.figure(figsize=(7, 6))
plt.hist(df.Merch_code)
plt.title('Распределение значений "код магазина"')
plt.show() #что есть код магазина? 70 уникальных значений

# %% [markdown]
# ##### 1.2.1.10 Goods_category Категория товара

# %%
plt.figure(figsize=(12, 6))
plt.hist(df.Goods_category)
plt.title('Распределение значений "Категория товара"')
plt.show() #видим равнозначное распределение, тут наверное нечего менять

# %% [markdown]
# #### 1.2.2 Числовые столбцы

# %% [markdown]
# ##### 1.2.2.1 MonthProfit Месячная зарплата

# %%
df.MonthProfit.max() #1млн 200 тысяч в месяц? аномалия?
# Out:
# 1200000

# %%
df.MonthProfit.min() #чо, аномалия 50 рублей в месяц?
# Out:
# 50

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.MonthProfit/10)#для лучшей читаемости зп на графике просто умножаем на 10
plt.title('Распределение значений "Месячной зарплаты поделённой на 10"')
plt.show()

# %%
df.MonthProfit.value_counts()
# Out:
# 150000    611
# 100000    603
# 200000    566
# 120000    440
# 250000    330
#          ...
# 75215       1
# 87600       1
# 87542       1
# 75800       1
# 45675       1
# Name: MonthProfit, Length: 292, dtype: Int64

# %% [markdown]
# ##### 1.2.2.2 MonthExpense Ежемесячный расход

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.MonthExpense)
plt.title('Распределение значений "ежемесячные расходы"')
plt.show()# кто-то тратит 0,5 млн руб?

# %%
df.MonthExpense.value_counts()
# Out:
# 30000     883
# 15000     603
# 20000     391
# 40000     373
# 25000     331
#          ...
# 2543        1
# 18750       1
# 13100       1
# 140000      1
# 39780       1
# Name: MonthExpense, Length: 206, dtype: Int64

# %%
df.MonthExpense.min() #нет ежемесячных расходов????
# Out:
# 0

# %%
df['Income_Expense_Ratio'] = np.where(df['MonthExpense'] != 0, df['MonthProfit'] / df['MonthExpense'], np.nan)

df[['MonthProfit', 'MonthExpense', 'Income_Expense_Ratio']]
# Out:
#       MonthProfit  MonthExpense Income_Expense_Ratio
# 0          180000         90000                  2.0
# 1          200000         60000             3.333333
# 2          300000         45000             6.666667
# 3          300000         45000             6.666667
# 4          300000         45000             6.666667
# ...           ...           ...                  ...
# 6598       125000         15000             8.333333
# 6599       150000         14000            10.714286
# 6600       130000         30000             4.333333
# 6601       150000         10000                 15.0
# 6602       150000         10000                 15.0
#
# [6464 rows x 3 columns]

# %%
# Фильтрация DataFrame для отношений меньше или равных 10
filtered_df = df[df['Income_Expense_Ratio'] <= 10]
# Создание ящиковой диаграммы для 'Income_Expense_Ratio'
plt.figure(figsize=(10, 6))
sns.boxplot(x=filtered_df['Income_Expense_Ratio'], color='skyblue')
plt.title('Ящиковая диаграмма отношения Дохода к Расходу (<= 10)')
plt.xlabel('Отношение Дохода к Расходу')
plt.show()

# %% [markdown]
# ##### 1.2.2.3 Loan_amount Сумма заказа

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.Loan_amount)
plt.title('Распределение значений "Сумма заказа"')
plt.show()# не более 200 тыс руб сумма заказа

# %% [markdown]
# ##### 1.2.2.4 Loan_term Срок кредита

# %%
plt.figure(figsize=(22, 6))
plt.hist(df.Loan_term)
plt.title('Распределение значений "Срок кредита"')
plt.show() # срок кредита не больше двух лет

# %% [markdown]
# #### 1.2.3 Дата

# %% [markdown]
# ##### 1.2.3.1 JobStartDate Дата начала работы (Дата начала работы -> Лет отработал)

# %%
current_date = pd.Timestamp('2023-11-11')
# Преобразуйте строковую дату в Timestamp
df['JobStartDate'] = pd.to_datetime(df['JobStartDate'])
# Преобразуйте возраст для каждой даты в датасете
df['work_age'] = ((current_date - df['JobStartDate']).dt.days / 365.25).round(1)

# %%
df.work_age.min(), df.work_age.max() #количество проработанных лет
# Out:
# (0.4, 50.2)

# %% [markdown]
# ##### 1.2.3.2 BirthDate Дата рождения (Дата рождения -> возраст)

# %%
df.BirthDate
# Out:
# 0      1988-07-21
# 1      1998-01-16
# 2      1972-10-02
# 3      1972-10-02
# 4      1972-10-02
#           ...
# 6598   1975-09-07
# 6599   1985-04-20
# 6600   1987-12-19
# 6601   2003-10-05
# 6602   2003-10-05
# Name: BirthDate, Length: 6464, dtype: datetime64[ns]

# %%
current_date = pd.Timestamp('2023-11-11')
# Преобразуйте строковую дату в Timestamp
df['BirthDate'] = pd.to_datetime(df['BirthDate'])
# Преобразуйте возраст для каждой даты в датасете
df['age'] = ((current_date - df['BirthDate']).dt.days / 365.25).round(1)

# %%
df.age.max(), df.age.min() #запросы совершались в 2023 году?
# Out:
# (83.6, 18.5)

# %% [markdown]
# #### 1.2.4 Целевая метка (Решение банков)
# тут модно бернуть в вероятность:
# все откажут - 0
# все согласятся - 1
# согласятся 4 банка 0.8
# согласится один банк - 0.2 и т.п.

# %%
bank_decision = ['BankA_decision', 'BankB_decision', 'BankC_decision', 'BankD_decision', 'BankE_decision']
for bank in bank_decision:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=bank, data=df)
    plt.title(f'Distribution of {bank}')
    plt.show()

# %%
bank_list = ['BankA_decision', 'BankB_decision', 'BankC_decision', 'BankD_decision', 'BankE_decision']

plt.figure(figsize=(7, 6))
plt.hist(df[bank_list])
plt.title('Распределение значений "решения банков"')
plt.show()#; строки с error отбрасываем? #МОЖНО СДЕЛАТЬ

# %%
# Создание DataFrame, содержащего только столбцы с решениями банка
bank_decisions_df = df[bank_list]
# Сопоставление 'success' и 'denied' с числовыми значениями (1 и 0)
bank_decisions_df_numeric = bank_decisions_df.apply(lambda x: x.map({'success': 1, 'denied': 0, 'error': 0}))
# Вычисление матрицы корреляции
correlation_matrix = bank_decisions_df_numeric.corr()
# Создание тепловой карты
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Тепловая карта корреляции для решений банка')
plt.show()

# %%
df[bank_list][df[bank_list] == 'success']
# Out:
#      BankA_decision BankB_decision BankC_decision BankD_decision  \
# 0           success        success        success        success
# 1           success            NaN        success            NaN
# 2               NaN            NaN        success        success
# 3           success            NaN        success        success
# 4           success            NaN        success        success
# ...             ...            ...            ...            ...
# 6598        success        success        success        success
# 6599            NaN        success        success        success
# 6600        success        success        success        success
# 6601        success        success        success        success
# 6602            NaN        success        success        success
#
#      BankE_decision
# 0               NaN
# 1           success
# 2           success
# 3           success
# 4           success
# ...             ...
# 6598        success
# 6599            NaN
# 6600        success
# 6601        success
# 6602        success
#
# [6464 rows x 5 columns]

# %%
for element in bank_list:#кодирую новые 5 столбцов для получения информация об error
  df[element+'_error'] = df[element].map({'error': 1,'success': 0,'denied': 0})
  #print(element+'_')

# %%
bank_list_error = ['BankA_decision_error', 'BankB_decision_error', 'BankC_decision_error', 'BankD_decision_error', 'BankE_decision_error']

# %%
for element in bank_list_error:
  print(element,df[element].sum())# количество ошибок от банков
# Out:
# BankA_decision_error 69
# BankB_decision_error 75
# BankC_decision_error 60
# BankD_decision_error 75
# BankE_decision_error 70

# %%
for element in bank_list:#кодирую новые 5 столбцов для получения информация об error
  df[element+'_success'] = df[element].map({'error': 0,'success': 1,'denied': 0})

# %%
bank_list_success = ['BankA_decision_success', 'BankB_decision_success', 'BankC_decision_success', 'BankD_decision_success', 'BankE_decision_success']

plt.figure(figsize=(7, 6))
plt.hist(df[bank_list_success])
plt.title('Распределение значений "решения банков"')
plt.show()#;

# %%
# Список агрегатных функций
aggregate_functions = [ 'count', 'max', 'min', 'mean']
# Создаем фигуры и оси графиков
fig, axes = plt.subplots(len(aggregate_functions), 1, figsize=(6, 4*len(aggregate_functions)))
# Цикл по агрегатным функциям
for i, agg_func in enumerate(aggregate_functions):
    # Создаем сводную таблицу с текущей агрегатной функцией
    pivot_table = df.pivot_table(values='MonthProfit', index=['BankA_decision_success', 'BankB_decision_success', 'BankC_decision_success', 'BankD_decision_success', 'BankE_decision_success'], aggfunc=agg_func).reset_index()
    # Объединяем значения столбцев в одну строку
    pivot_table['bank'] = pivot_table[['BankA_decision_success', 'BankB_decision_success', 'BankC_decision_success', 'BankD_decision_success', 'BankE_decision_success']].apply(lambda x: ', '.join(map(str, x)), axis=1)
    # Создаем график для текущей агрегатной функции
    ax = axes[i]
    pivot_table.plot(x='bank', y='MonthProfit', kind='bar', ax=ax)
    # Настройка осей и заголовка графика
    ax.set_xlabel('Комбинация hot, snow, rain')
    ax.set_ylabel(agg_func.capitalize())  # Первая буква заглавная
    ax.set_title(f'Распределение {agg_func} по решениям банков')
# Размещение графиков на фигуре
plt.tight_layout()
plt.show()

# %%
education_categories = df['education'].unique()
total_counts = len(df)
for element in bank_list:
    for education_category in education_categories:
        print(f"Education Category: {education_category}")
        education_subset = df[df['education'] == education_category]
        bank_counts = education_subset[element].value_counts(normalize=True) * 100

        for decision, percentage in bank_counts.items():
            print(f" {element}={decision}: {percentage:.2f}%")

        print()
# Out:
# Education Category: Высшее - специалист
#  BankA_decision=success: 75.14%
#  BankA_decision=denied: 23.81%
#  BankA_decision=error: 1.05%
#
# Education Category: Неоконченное среднее
#  BankA_decision=success: 76.92%
#  BankA_decision=denied: 19.23%
#  BankA_decision=error: 3.85%
#
# Education Category: Среднее профессиональное
#  BankA_decision=success: 71.11%
#  BankA_decision=denied: 27.09%
#  BankA_decision=error: 1.81%
#
# Education Category: Среднее
#  BankA_decision=success: 80.41%
#  BankA_decision=denied: 19.07%
#  BankA_decision=error: 0.52%
#
# Education Category: Магистр
#  BankA_decision=success: 67.61%
#  BankA_decision=denied: 30.99%
#  BankA_decision=error: 1.41%
#
# Education Category: Несколько высших
#  BankA_decision=success: 73.39%
#  BankA_decision=denied: 26.61%
#
# Education Category: Бакалавр
#  BankA_decision=success: 79.86%
#  BankA_decision=denied: 18.75%
#  BankA_decision=error: 1.39%
#
# Education Category: Неоконченное высшее
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 19.53%
#  BankA_decision=error: 0.47%
#
# Education Category: MBA
#  BankA_decision=success: 66.67%
#  BankA_decision=denied: 33.33%
#
# Education Category: Ученая степень
#  BankA_decision=success: 100.00%
#
# Education Category: Высшее - специалист
#  BankB_decision=success: 73.93%
#  BankB_decision=denied: 24.93%
#  BankB_decision=error: 1.14%
#
# Education Category: Неоконченное среднее
#  BankB_decision=success: 80.77%
#  BankB_decision=denied: 19.23%
#
# Education Category: Среднее профессиональное
#  BankB_decision=success: 76.75%
#  BankB_decision=denied: 22.57%
#  BankB_decision=error: 0.68%
#
# Education Category: Среднее
#  BankB_decision=success: 75.77%
#  BankB_decision=denied: 23.20%
#  BankB_decision=error: 1.03%
#
# Education Category: Магистр
#  BankB_decision=success: 70.42%
#  BankB_decision=denied: 28.17%
#  BankB_decision=error: 1.41%
#
# Education Category: Несколько высших
#  BankB_decision=success: 73.39%
#  BankB_decision=denied: 23.85%
#  BankB_decision=error: 2.75%
#
# Education Category: Бакалавр
#  BankB_decision=success: 77.78%
#  BankB_decision=denied: 18.75%
#  BankB_decision=error: 3.47%
#
# Education Category: Неоконченное высшее
#  BankB_decision=success: 74.88%
#  BankB_decision=denied: 24.65%
#  BankB_decision=error: 0.47%
#
# Education Category: MBA
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Education Category: Ученая степень
#  BankB_decision=success: 100.00%
#
# Education Category: Высшее - специалист
#  BankC_decision=success: 74.91%
#  BankC_decision=denied: 24.25%
#  BankC_decision=error: 0.84%
#
# Education Category: Неоконченное среднее
#  BankC_decision=success: 65.38%
#  BankC_decision=denied: 30.77%
#  BankC_decision=error: 3.85%
#
# Education Category: Среднее профессиональное
#  BankC_decision=success: 74.27%
#  BankC_decision=denied: 24.15%
#  BankC_decision=error: 1.58%
#
# Education Category: Среднее
#  BankC_decision=success: 77.32%
#  BankC_decision=denied: 22.16%
#  BankC_decision=error: 0.52%
#
# Education Category: Магистр
#  BankC_decision=success: 77.46%
#  BankC_decision=denied: 19.72%
#  BankC_decision=error: 2.82%
#
# Education Category: Несколько высших
#  BankC_decision=success: 69.72%
#  BankC_decision=denied: 30.28%
#
# Education Category: Бакалавр
#  BankC_decision=success: 70.14%
#  BankC_decision=denied: 27.78%
#  BankC_decision=error: 2.08%
#
# Education Category: Неоконченное высшее
#  BankC_decision=success: 75.81%
#  BankC_decision=denied: 23.26%
#  BankC_decision=error: 0.93%
#
# Education Category: MBA
#  BankC_decision=denied: 66.67%
#  BankC_decision=success: 33.33%
#
# Education Category: Ученая степень
#  BankC_decision=success: 100.00%
#
# Education Category: Высшее - специалист
#  BankD_decision=success: 75.12%
#  BankD_decision=denied: 23.75%
#  BankD_decision=error: 1.12%
#
# Education Category: Неоконченное среднее
#  BankD_decision=success: 65.38%
#  BankD_decision=denied: 34.62%
#
# Education Category: Среднее профессиональное
#  BankD_decision=success: 73.14%
#  BankD_decision=denied: 24.83%
#  BankD_decision=error: 2.03%
#
# Education Category: Среднее
#  BankD_decision=success: 74.23%
#  BankD_decision=denied: 24.23%
#  BankD_decision=error: 1.55%
#
# Education Category: Магистр
#  BankD_decision=success: 71.83%
#  BankD_decision=denied: 28.17%
#
# Education Category: Несколько высших
#  BankD_decision=success: 73.39%
#  BankD_decision=denied: 25.69%
#  BankD_decision=error: 0.92%
#
# Education Category: Бакалавр
#  BankD_decision=success: 78.47%
#  BankD_decision=denied: 20.83%
#  BankD_decision=error: 0.69%
#
# Education Category: Неоконченное высшее
#  BankD_decision=success: 74.42%
#  BankD_decision=denied: 24.65%
#  BankD_decision=error: 0.93%
#
# Education Category: MBA
#  BankD_decision=success: 66.67%
#  BankD_decision=denied: 33.33%
#
# Education Category: Ученая степень
#  BankD_decision=success: 100.00%
#
# Education Category: Высшее - специалист
#  BankE_decision=success: 74.86%
#  BankE_decision=denied: 24.08%
#  BankE_decision=error: 1.07%
#
# Education Category: Неоконченное среднее
#  BankE_decision=success: 84.62%
#  BankE_decision=denied: 15.38%
#
# Education Category: Среднее профессиональное
#  BankE_decision=success: 73.14%
#  BankE_decision=denied: 25.73%
#  BankE_decision=error: 1.13%
#
# Education Category: Среднее
#  BankE_decision=success: 76.80%
#  BankE_decision=denied: 22.16%
#  BankE_decision=error: 1.03%
#
# Education Category: Магистр
#  BankE_decision=success: 80.28%
#  BankE_decision=denied: 18.31%
#  BankE_decision=error: 1.41%
#
# Education Category: Несколько высших
#  BankE_decision=success: 77.98%
#  BankE_decision=denied: 21.10%
#  BankE_decision=error: 0.92%
#
# Education Category: Бакалавр
#  BankE_decision=success: 77.08%
#  BankE_decision=denied: 20.83%
#  BankE_decision=error: 2.08%
#
# Education Category: Неоконченное высшее
#  BankE_decision=success: 71.63%
#  BankE_decision=denied: 27.44%
#  BankE_decision=error: 0.93%
#
# Education Category: MBA
#  BankE_decision=success: 100.00%
#
# Education Category: Ученая степень
#  BankE_decision=success: 100.00%

# %%
df.columns
# Out:
# Index(['SkillFactory_Id', 'BirthDate', 'education', 'employment status',
#        'Value', 'JobStartDate', 'Position', 'MonthProfit', 'MonthExpense',
#        'Gender', 'Family status', 'ChildCount', 'SNILS', 'BankA_decision',
#        'BankB_decision', 'BankC_decision', 'BankD_decision', 'BankE_decision',
#        'Merch_code', 'Loan_amount', 'Loan_term', 'Goods_category',
#        'Income_Expense_Ratio', 'work_age', 'age', 'BankA_decision_error',
#        'BankB_decision_error', 'BankC_decision_error', 'BankD_decision_error',
#        'BankE_decision_error', 'BankA_decision_success',
#        'BankB_decision_success', 'BankC_decision_success',
#        'BankD_decision_success', 'BankE_decision_success'],
#       dtype='object')

# %%
#по всему датасету, но надо придумать как нормально это просматривать
dfColumns = ['education', 'employment status',
       'Value',
       'Gender', 'Family status', 'ChildCount', 'SNILS',
       'Merch_code', 'Loan_amount', 'Loan_term', 'Goods_category']
for datasetElement in dfColumns:
  categories = df[datasetElement].unique()
  for element in bank_list:
    for category in categories:
        print(f"{datasetElement}: {category}")
        subset = df[df[datasetElement] == category]
        bank_counts = subset[element].value_counts(normalize=True) * 100
        for decision, percentage in bank_counts.items():
            print(f" {element}={decision}: {percentage:.2f}%")

        print()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Merch_code: 70
#  BankD_decision=success: 74.12%
#  BankD_decision=denied: 23.53%
#  BankD_decision=error: 2.35%
#
# Merch_code: 29
#  BankD_decision=success: 76.09%
#  BankD_decision=denied: 22.83%
#  BankD_decision=error: 1.09%
#
# Merch_code: 6
#  BankD_decision=success: 83.54%
#  BankD_decision=denied: 16.46%
#
# Merch_code: 28
#  BankD_decision=success: 87.36%
#  BankD_decision=denied: 12.64%
#
# Merch_code: 24
#  BankD_decision=success: 82.61%
#  BankD_decision=denied: 15.22%
#  BankD_decision=error: 2.17%
#
# Merch_code: 38
#  BankD_decision=success: 80.43%
#  BankD_decision=denied: 17.39%
#  BankD_decision=error: 2.17%
#
# Merch_code: 63
#  BankD_decision=success: 79.61%
#  BankD_decision=denied: 19.42%
#  BankD_decision=error: 0.97%
#
# Merch_code: 44
#  BankD_decision=success: 77.78%
#  BankD_decision=denied: 22.22%
#
# Merch_code: 32
#  BankD_decision=success: 74.16%
#  BankD_decision=denied: 25.84%
#
# Merch_code: 10
#  BankD_decision=success: 72.00%
#  BankD_decision=denied: 25.00%
#  BankD_decision=error: 3.00%
#
# Merch_code: 74
#  BankD_decision=success: 71.03%
#  BankD_decision=denied: 28.04%
#  BankD_decision=error: 0.93%
#
# Merch_code: 50
#  BankD_decision=success: 80.00%
#  BankD_decision=denied: 20.00%
#
# Merch_code: 23
#  BankD_decision=success: 74.19%
#  BankD_decision=denied: 25.81%
#
# Merch_code: 49
#  BankD_decision=success: 74.23%
#  BankD_decision=denied: 23.71%
#  BankD_decision=error: 2.06%
#
# Merch_code: 69
#  BankD_decision=success: 73.26%
#  BankD_decision=denied: 25.58%
#  BankD_decision=error: 1.16%
#
# Merch_code: 4
#  BankD_decision=success: 68.89%
#  BankD_decision=denied: 30.00%
#  BankD_decision=error: 1.11%
#
# Merch_code: 1
#  BankD_decision=success: 78.65%
#  BankD_decision=denied: 17.98%
#  BankD_decision=error: 3.37%
#
# Merch_code: 39
#  BankD_decision=success: 73.74%
#  BankD_decision=denied: 23.23%
#  BankD_decision=error: 3.03%
#
# Merch_code: 66
#  BankD_decision=success: 75.32%
#  BankD_decision=denied: 22.08%
#  BankD_decision=error: 2.60%
#
# Merch_code: 13
#  BankD_decision=success: 77.89%
#  BankD_decision=denied: 20.00%
#  BankD_decision=error: 2.11%
#
# Merch_code: 16
#  BankD_decision=success: 75.26%
#  BankD_decision=denied: 24.74%
#
# Merch_code: 2
#  BankD_decision=success: 73.56%
#  BankD_decision=denied: 25.29%
#  BankD_decision=error: 1.15%
#
# Merch_code: 9
#  BankD_decision=success: 77.91%
#  BankD_decision=denied: 20.93%
#  BankD_decision=error: 1.16%
#
# Merch_code: 14
#  BankD_decision=success: 68.48%
#  BankD_decision=denied: 30.43%
#  BankD_decision=error: 1.09%
#
# Merch_code: 21
#  BankD_decision=success: 69.41%
#  BankD_decision=denied: 30.59%
#
# Merch_code: 62
#  BankD_decision=success: 75.93%
#  BankD_decision=denied: 23.15%
#  BankD_decision=error: 0.93%
#
# Merch_code: 64
#  BankD_decision=success: 70.33%
#  BankD_decision=denied: 29.67%
#
# Merch_code: 79
#  BankD_decision=success: 73.79%
#  BankD_decision=denied: 26.21%
#
# Merch_code: 71
#  BankD_decision=success: 60.00%
#  BankD_decision=denied: 40.00%
#
# Merch_code: 26
#  BankD_decision=success: 71.59%
#  BankD_decision=denied: 26.14%
#  BankD_decision=error: 2.27%
#
# Merch_code: 17
#  BankD_decision=success: 68.82%
#  BankD_decision=denied: 30.11%
#  BankD_decision=error: 1.08%
#
# Merch_code: 76
#  BankD_decision=success: 79.81%
#  BankD_decision=denied: 19.23%
#  BankD_decision=error: 0.96%
#
# Merch_code: 73
#  BankD_decision=success: 75.96%
#  BankD_decision=denied: 23.08%
#  BankD_decision=error: 0.96%
#
# Merch_code: 20
#  BankD_decision=success: 81.11%
#  BankD_decision=denied: 18.89%
#
# Merch_code: 46
#  BankD_decision=success: 75.53%
#  BankD_decision=denied: 23.40%
#  BankD_decision=error: 1.06%
#
# Merch_code: 35
#  BankD_decision=success: 69.72%
#  BankD_decision=denied: 28.44%
#  BankD_decision=error: 1.83%
#
# Merch_code: 7
#  BankD_decision=success: 64.29%
#  BankD_decision=denied: 33.67%
#  BankD_decision=error: 2.04%
#
# Merch_code: 5
#  BankD_decision=success: 79.31%
#  BankD_decision=denied: 18.39%
#  BankD_decision=error: 2.30%
#
# Merch_code: 41
#  BankD_decision=success: 76.92%
#  BankD_decision=denied: 20.88%
#  BankD_decision=error: 2.20%
#
# Merch_code: 42
#  BankD_decision=success: 63.95%
#  BankD_decision=denied: 32.56%
#  BankD_decision=error: 3.49%
#
# Merch_code: 37
#  BankD_decision=success: 72.41%
#  BankD_decision=denied: 27.59%
#
# Merch_code: 68
#  BankD_decision=success: 77.27%
#  BankD_decision=denied: 22.73%
#
# Merch_code: 65
#  BankD_decision=success: 74.26%
#  BankD_decision=denied: 25.74%
#
# Merch_code: 77
#  BankE_decision=success: 85.06%
#  BankE_decision=denied: 13.79%
#  BankE_decision=error: 1.15%
#
# Merch_code: 27
#  BankE_decision=success: 69.41%
#  BankE_decision=denied: 28.24%
#  BankE_decision=error: 2.35%
#
# Merch_code: 19
#  BankE_decision=success: 72.62%
#  BankE_decision=denied: 27.38%
#
# Merch_code: 34
#  BankE_decision=success: 72.73%
#  BankE_decision=denied: 26.14%
#  BankE_decision=error: 1.14%
#
# Merch_code: 75
#  BankE_decision=success: 68.18%
#  BankE_decision=denied: 31.82%
#
# Merch_code: 33
#  BankE_decision=success: 75.27%
#  BankE_decision=denied: 22.58%
#  BankE_decision=error: 2.15%
#
# Merch_code: 8
#  BankE_decision=success: 77.91%
#  BankE_decision=denied: 22.09%
#
# Merch_code: 15
#  BankE_decision=success: 74.42%
#  BankE_decision=denied: 25.58%
#
# Merch_code: 80
#  BankE_decision=success: 75.58%
#  BankE_decision=denied: 20.93%
#  BankE_decision=error: 3.49%
#
# Merch_code: 78
#  BankE_decision=success: 66.67%
#  BankE_decision=denied: 31.25%
#  BankE_decision=error: 2.08%
#
# Merch_code: 43
#  BankE_decision=success: 81.19%
#  BankE_decision=denied: 16.83%
#  BankE_decision=error: 1.98%
#
# Merch_code: 61
#  BankE_decision=success: 75.73%
#  BankE_decision=denied: 24.27%
#
# Merch_code: 18
#  BankE_decision=success: 73.12%
#  BankE_decision=denied: 26.88%
#
# Merch_code: 72
#  BankE_decision=success: 72.00%
#  BankE_decision=denied: 26.67%
#  BankE_decision=error: 1.33%
#
# Merch_code: 45
#  BankE_decision=success: 81.00%
#  BankE_decision=denied: 19.00%
#
# Merch_code: 48
#  BankE_decision=success: 78.16%
#  BankE_decision=denied: 20.69%
#  BankE_decision=error: 1.15%
#
# Merch_code: 67
#  BankE_decision=success: 72.45%
#  BankE_decision=denied: 26.53%
#  BankE_decision=error: 1.02%
#
# Merch_code: 12
#  BankE_decision=success: 66.67%
#  BankE_decision=denied: 30.95%
#  BankE_decision=error: 2.38%
#
# Merch_code: 11
#  BankE_decision=success: 77.36%
#  BankE_decision=denied: 20.75%
#  BankE_decision=error: 1.89%
#
# Merch_code: 40
#  BankE_decision=success: 75.27%
#  BankE_decision=denied: 24.73%
#
# Merch_code: 36
#  BankE_decision=success: 74.39%
#  BankE_decision=denied: 25.61%
#
# Merch_code: 31
#  BankE_decision=success: 69.66%
#  BankE_decision=denied: 29.21%
#  BankE_decision=error: 1.12%
#
# Merch_code: 3
#  BankE_decision=success: 83.91%
#  BankE_decision=denied: 13.79%
#  BankE_decision=error: 2.30%
#
# Merch_code: 47
#  BankE_decision=success: 76.04%
#  BankE_decision=denied: 22.92%
#  BankE_decision=error: 1.04%
#
# Merch_code: 25
#  BankE_decision=success: 72.83%
#  BankE_decision=denied: 26.09%
#  BankE_decision=error: 1.09%
#
# Merch_code: 30
#  BankE_decision=success: 83.87%
#  BankE_decision=denied: 16.13%
#
# Merch_code: 22
#  BankE_decision=success: 78.00%
#  BankE_decision=denied: 22.00%
#
# Merch_code: 70
#  BankE_decision=success: 74.12%
#  BankE_decision=denied: 25.88%
#
# Merch_code: 29
#  BankE_decision=success: 79.35%
#  BankE_decision=denied: 18.48%
#  BankE_decision=error: 2.17%
#
# Merch_code: 6
#  BankE_decision=success: 68.35%
#  BankE_decision=denied: 27.85%
#  BankE_decision=error: 3.80%
#
# Merch_code: 28
#  BankE_decision=success: 78.16%
#  BankE_decision=denied: 21.84%
#
# Merch_code: 24
#  BankE_decision=success: 78.26%
#  BankE_decision=denied: 19.57%
#  BankE_decision=error: 2.17%
#
# Merch_code: 38
#  BankE_decision=success: 64.13%
#  BankE_decision=denied: 32.61%
#  BankE_decision=error: 3.26%
#
# Merch_code: 63
#  BankE_decision=success: 80.58%
#  BankE_decision=denied: 19.42%
#
# Merch_code: 44
#  BankE_decision=success: 81.11%
#  BankE_decision=denied: 16.67%
#  BankE_decision=error: 2.22%
#
# Merch_code: 32
#  BankE_decision=success: 77.53%
#  BankE_decision=denied: 20.22%
#  BankE_decision=error: 2.25%
#
# Merch_code: 10
#  BankE_decision=success: 80.00%
#  BankE_decision=denied: 17.00%
#  BankE_decision=error: 3.00%
#
# Merch_code: 74
#  BankE_decision=success: 83.18%
#  BankE_decision=denied: 15.89%
#  BankE_decision=error: 0.93%
#
# Merch_code: 50
#  BankE_decision=success: 76.84%
#  BankE_decision=denied: 23.16%
#
# Merch_code: 23
#  BankE_decision=success: 82.80%
#  BankE_decision=denied: 17.20%
#
# Merch_code: 49
#  BankE_decision=success: 74.23%
#  BankE_decision=denied: 22.68%
#  BankE_decision=error: 3.09%
#
# Merch_code: 69
#  BankE_decision=success: 67.44%
#  BankE_decision=denied: 30.23%
#  BankE_decision=error: 2.33%
#
# Merch_code: 4
#  BankE_decision=success: 70.00%
#  BankE_decision=denied: 30.00%
#
# Merch_code: 1
#  BankE_decision=success: 76.40%
#  BankE_decision=denied: 23.60%
#
# Merch_code: 39
#  BankE_decision=success: 68.69%
#  BankE_decision=denied: 30.30%
#  BankE_decision=error: 1.01%
#
# Merch_code: 66
#  BankE_decision=success: 63.64%
#  BankE_decision=denied: 32.47%
#  BankE_decision=error: 3.90%
#
# Merch_code: 13
#  BankE_decision=success: 74.74%
#  BankE_decision=denied: 24.21%
#  BankE_decision=error: 1.05%
#
# Merch_code: 16
#  BankE_decision=success: 71.13%
#  BankE_decision=denied: 28.87%
#
# Merch_code: 2
#  BankE_decision=success: 74.71%
#  BankE_decision=denied: 25.29%
#
# Merch_code: 9
#  BankE_decision=success: 77.91%
#  BankE_decision=denied: 22.09%
#
# Merch_code: 14
#  BankE_decision=success: 67.39%
#  BankE_decision=denied: 32.61%
#
# Merch_code: 21
#  BankE_decision=success: 72.94%
#  BankE_decision=denied: 25.88%
#  BankE_decision=error: 1.18%
#
# Merch_code: 62
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 24.07%
#  BankE_decision=error: 0.93%
#
# Merch_code: 64
#  BankE_decision=success: 75.82%
#  BankE_decision=denied: 24.18%
#
# Merch_code: 79
#  BankE_decision=success: 71.84%
#  BankE_decision=denied: 28.16%
#
# Merch_code: 71
#  BankE_decision=success: 78.00%
#  BankE_decision=denied: 21.00%
#  BankE_decision=error: 1.00%
#
# Merch_code: 26
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 22.73%
#  BankE_decision=error: 2.27%
#
# Merch_code: 17
#  BankE_decision=success: 77.42%
#  BankE_decision=denied: 21.51%
#  BankE_decision=error: 1.08%
#
# Merch_code: 76
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 22.12%
#  BankE_decision=error: 2.88%
#
# Merch_code: 73
#  BankE_decision=success: 75.96%
#  BankE_decision=denied: 23.08%
#  BankE_decision=error: 0.96%
#
# Merch_code: 20
#  BankE_decision=success: 81.11%
#  BankE_decision=denied: 18.89%
#
# Merch_code: 46
#  BankE_decision=success: 71.28%
#  BankE_decision=denied: 26.60%
#  BankE_decision=error: 2.13%
#
# Merch_code: 35
#  BankE_decision=success: 72.48%
#  BankE_decision=denied: 27.52%
#
# Merch_code: 7
#  BankE_decision=success: 72.45%
#  BankE_decision=denied: 26.53%
#  BankE_decision=error: 1.02%
#
# Merch_code: 5
#  BankE_decision=success: 65.52%
#  BankE_decision=denied: 32.18%
#  BankE_decision=error: 2.30%
#
# Merch_code: 41
#  BankE_decision=success: 75.82%
#  BankE_decision=denied: 23.08%
#  BankE_decision=error: 1.10%
#
# Merch_code: 42
#  BankE_decision=success: 81.40%
#  BankE_decision=denied: 18.60%
#
# Merch_code: 37
#  BankE_decision=success: 78.16%
#  BankE_decision=denied: 21.84%
#
# Merch_code: 68
#  BankE_decision=success: 71.59%
#  BankE_decision=denied: 27.27%
#  BankE_decision=error: 1.14%
#
# Merch_code: 65
#  BankE_decision=success: 70.30%
#  BankE_decision=denied: 29.70%
#
# Loan_amount: 137000
#  BankA_decision=success: 78.57%
#  BankA_decision=denied: 21.43%
#
# Loan_amount: 33000
#  BankA_decision=success: 79.25%
#  BankA_decision=denied: 20.75%
#
# Loan_amount: 165000
#  BankA_decision=success: 69.23%
#  BankA_decision=denied: 23.08%
#  BankA_decision=error: 7.69%
#
# Loan_amount: 67000
#  BankA_decision=success: 69.23%
#  BankA_decision=denied: 26.92%
#  BankA_decision=error: 3.85%
#
# Loan_amount: 36000
#  BankA_decision=success: 71.70%
#  BankA_decision=denied: 26.42%
#  BankA_decision=error: 1.89%
#
# Loan_amount: 47000
#  BankA_decision=success: 76.47%
#  BankA_decision=denied: 22.06%
#  BankA_decision=error: 1.47%
#
# Loan_amount: 175000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 74000
#  BankA_decision=success: 72.73%
#  BankA_decision=denied: 25.76%
#  BankA_decision=error: 1.52%
#
# Loan_amount: 82000
#  BankA_decision=success: 69.57%
#  BankA_decision=denied: 23.91%
#  BankA_decision=error: 6.52%
#
# Loan_amount: 171000
#  BankA_decision=success: 100.00%
#
# Loan_amount: 72000
#  BankA_decision=success: 75.47%
#  BankA_decision=denied: 24.53%
#
# Loan_amount: 57000
#  BankA_decision=success: 60.94%
#  BankA_decision=denied: 37.50%
#  BankA_decision=error: 1.56%
#
# Loan_amount: 119000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 16.67%
#
# Loan_amount: 138000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 16.67%
#
# Loan_amount: 92000
#  BankA_decision=success: 74.47%
#  BankA_decision=denied: 21.28%
#  BankA_decision=error: 4.26%
#
# Loan_amount: 34000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 28.57%
#
# Loan_amount: 110000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 4000
#  BankA_decision=success: 82.76%
#  BankA_decision=denied: 17.24%
#
# Loan_amount: 16000
#  BankA_decision=success: 75.41%
#  BankA_decision=denied: 24.59%
#
# Loan_amount: 31000
#  BankA_decision=success: 84.62%
#  BankA_decision=denied: 15.38%
#
# Loan_amount: 62000
#  BankA_decision=success: 78.85%
#  BankA_decision=denied: 19.23%
#  BankA_decision=error: 1.92%
#
# Loan_amount: 70000
#  BankA_decision=success: 67.50%
#  BankA_decision=denied: 27.50%
#  BankA_decision=error: 5.00%
#
# Loan_amount: 186000
#  BankA_decision=success: 92.86%
#  BankA_decision=denied: 7.14%
#
# Loan_amount: 133000
#  BankA_decision=denied: 50.00%
#  BankA_decision=success: 50.00%
#
# Loan_amount: 14000
#  BankA_decision=success: 77.78%
#  BankA_decision=denied: 18.52%
#  BankA_decision=error: 3.70%
#
# Loan_amount: 161000
#  BankA_decision=success: 66.67%
#  BankA_decision=denied: 33.33%
#
# Loan_amount: 64000
#  BankA_decision=success: 77.08%
#  BankA_decision=denied: 20.83%
#  BankA_decision=error: 2.08%
#
# Loan_amount: 12000
#  BankA_decision=success: 70.91%
#  BankA_decision=denied: 29.09%
#
# Loan_amount: 13000
#  BankA_decision=success: 84.31%
#  BankA_decision=denied: 15.69%
#
# Loan_amount: 153000
#  BankA_decision=success: 89.47%
#  BankA_decision=denied: 10.53%
#
# Loan_amount: 83000
#  BankA_decision=success: 65.12%
#  BankA_decision=denied: 34.88%
#
# Loan_amount: 42000
#  BankA_decision=success: 68.33%
#  BankA_decision=denied: 30.00%
#  BankA_decision=error: 1.67%
#
# Loan_amount: 76000
#  BankA_decision=success: 63.83%
#  BankA_decision=denied: 36.17%
#
# Loan_amount: 26000
#  BankA_decision=success: 74.58%
#  BankA_decision=denied: 25.42%
#
# Loan_amount: 123000
#  BankA_decision=success: 88.24%
#  BankA_decision=denied: 11.76%
#
# Loan_amount: 41000
#  BankA_decision=success: 72.55%
#  BankA_decision=denied: 23.53%
#  BankA_decision=error: 3.92%
#
# Loan_amount: 108000
#  BankA_decision=success: 68.42%
#  BankA_decision=denied: 31.58%
#
# Loan_amount: 38000
#  BankA_decision=success: 65.12%
#  BankA_decision=denied: 34.88%
#
# Loan_amount: 79000
#  BankA_decision=success: 77.55%
#  BankA_decision=denied: 18.37%
#  BankA_decision=error: 4.08%
#
# Loan_amount: 174000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 65000
#  BankA_decision=success: 68.89%
#  BankA_decision=denied: 31.11%
#
# Loan_amount: 95000
#  BankA_decision=success: 76.27%
#  BankA_decision=denied: 23.73%
#
# Loan_amount: 184000
#  BankA_decision=success: 63.16%
#  BankA_decision=denied: 36.84%
#
# Loan_amount: 80000
#  BankA_decision=success: 73.68%
#  BankA_decision=denied: 26.32%
#
# Loan_amount: 19000
#  BankA_decision=success: 69.77%
#  BankA_decision=denied: 27.91%
#  BankA_decision=error: 2.33%
#
# Loan_amount: 87000
#  BankA_decision=success: 85.25%
#  BankA_decision=denied: 13.11%
#  BankA_decision=error: 1.64%
#
# Loan_amount: 139000
#  BankA_decision=success: 94.12%
#  BankA_decision=denied: 5.88%
#
# Loan_amount: 198000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 145000
#  BankA_decision=success: 78.95%
#  BankA_decision=denied: 21.05%
#
# Loan_amount: 125000
#  BankA_decision=success: 80.95%
#  BankA_decision=denied: 19.05%
#
# Loan_amount: 46000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 20.00%
#
# Loan_amount: 90000
#  BankA_decision=success: 73.33%
#  BankA_decision=denied: 24.44%
#  BankA_decision=error: 2.22%
#
# Loan_amount: 17000
#  BankA_decision=success: 83.93%
#  BankA_decision=denied: 16.07%
#
# Loan_amount: 27000
#  BankA_decision=success: 71.88%
#  BankA_decision=denied: 26.56%
#  BankA_decision=error: 1.56%
#
# Loan_amount: 86000
#  BankA_decision=success: 76.74%
#  BankA_decision=denied: 20.93%
#  BankA_decision=error: 2.33%
#
# Loan_amount: 71000
#  BankA_decision=success: 69.57%
#  BankA_decision=denied: 30.43%
#
# Loan_amount: 194000
#  BankA_decision=success: 90.00%
#  BankA_decision=denied: 10.00%
#
# Loan_amount: 50000
#  BankA_decision=success: 70.45%
#  BankA_decision=denied: 29.55%
#
# Loan_amount: 48000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 14.81%
#  BankA_decision=error: 1.85%
#
# Loan_amount: 177000
#  BankA_decision=success: 66.67%
#  BankA_decision=denied: 33.33%
#
# Loan_amount: 89000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 16.67%
#  BankA_decision=error: 2.08%
#
# Loan_amount: 45000
#  BankA_decision=success: 67.39%
#  BankA_decision=denied: 32.61%
#
# Loan_amount: 53000
#  BankA_decision=success: 73.58%
#  BankA_decision=denied: 26.42%
#
# Loan_amount: 144000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 28.57%
#
# Loan_amount: 60000
#  BankA_decision=success: 69.39%
#  BankA_decision=denied: 30.61%
#
# Loan_amount: 78000
#  BankA_decision=success: 59.57%
#  BankA_decision=denied: 40.43%
#
# Loan_amount: 200000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 29.41%
#
# Loan_amount: 18000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 16.67%
#
# Loan_amount: 58000
#  BankA_decision=success: 76.92%
#  BankA_decision=denied: 23.08%
#
# Loan_amount: 43000
#  BankA_decision=success: 81.97%
#  BankA_decision=denied: 18.03%
#
# Loan_amount: 21000
#  BankA_decision=success: 72.73%
#  BankA_decision=denied: 27.27%
#
# Loan_amount: 55000
#  BankA_decision=success: 73.33%
#  BankA_decision=denied: 26.67%
#
# Loan_amount: 29000
#  BankA_decision=success: 78.33%
#  BankA_decision=denied: 20.00%
#  BankA_decision=error: 1.67%
#
# Loan_amount: 88000
#  BankA_decision=success: 76.47%
#  BankA_decision=denied: 23.53%
#
# Loan_amount: 116000
#  BankA_decision=success: 80.95%
#  BankA_decision=denied: 19.05%
#
# Loan_amount: 8000
#  BankA_decision=success: 75.47%
#  BankA_decision=denied: 24.53%
#
# Loan_amount: 152000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 156000
#  BankA_decision=success: 54.55%
#  BankA_decision=denied: 45.45%
#
# Loan_amount: 30000
#  BankA_decision=success: 79.17%
#  BankA_decision=denied: 16.67%
#  BankA_decision=error: 4.17%
#
# Loan_amount: 77000
#  BankA_decision=success: 76.00%
#  BankA_decision=denied: 24.00%
#
# Loan_amount: 104000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 91000
#  BankA_decision=success: 81.63%
#  BankA_decision=denied: 16.33%
#  BankA_decision=error: 2.04%
#
# Loan_amount: 15000
#  BankA_decision=success: 63.41%
#  BankA_decision=denied: 34.15%
#  BankA_decision=error: 2.44%
#
# Loan_amount: 172000
#  BankA_decision=success: 78.57%
#  BankA_decision=denied: 21.43%
#
# Loan_amount: 99000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 17.78%
#  BankA_decision=error: 2.22%
#
# Loan_amount: 59000
#  BankA_decision=success: 66.67%
#  BankA_decision=denied: 33.33%
#
# Loan_amount: 81000
#  BankA_decision=success: 87.10%
#  BankA_decision=denied: 12.90%
#
# Loan_amount: 22000
#  BankA_decision=success: 81.40%
#  BankA_decision=denied: 16.28%
#  BankA_decision=error: 2.33%
#
# Loan_amount: 141000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 29.41%
#
# Loan_amount: 105000
#  BankA_decision=success: 100.00%
#
# Loan_amount: 75000
#  BankA_decision=success: 73.91%
#  BankA_decision=denied: 26.09%
#
# Loan_amount: 191000
#  BankA_decision=success: 86.96%
#  BankA_decision=denied: 13.04%
#
# Loan_amount: 179000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 28.57%
#
# Loan_amount: 11000
#  BankA_decision=success: 73.33%
#  BankA_decision=denied: 26.67%
#
# Loan_amount: 49000
#  BankA_decision=success: 79.55%
#  BankA_decision=denied: 20.45%
#
# Loan_amount: 147000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 28000
#  BankA_decision=success: 78.43%
#  BankA_decision=denied: 19.61%
#  BankA_decision=error: 1.96%
#
# Loan_amount: 140000
#  BankA_decision=success: 69.23%
#  BankA_decision=denied: 23.08%
#  BankA_decision=error: 7.69%
#
# Loan_amount: 135000
#  BankA_decision=success: 85.71%
#  BankA_decision=denied: 14.29%
#
# Loan_amount: 132000
#  BankA_decision=success: 92.86%
#  BankA_decision=denied: 7.14%
#
# Loan_amount: 151000
#  BankA_decision=success: 78.26%
#  BankA_decision=denied: 21.74%
#
# Loan_amount: 128000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 94000
#  BankA_decision=success: 78.85%
#  BankA_decision=denied: 21.15%
#
# Loan_amount: 96000
#  BankA_decision=success: 72.92%
#  BankA_decision=denied: 27.08%
#
# Loan_amount: 10000
#  BankA_decision=success: 78.18%
#  BankA_decision=denied: 20.00%
#  BankA_decision=error: 1.82%
#
# Loan_amount: 114000
#  BankA_decision=success: 68.75%
#  BankA_decision=denied: 25.00%
#  BankA_decision=error: 6.25%
#
# Loan_amount: 106000
#  BankA_decision=success: 89.47%
#  BankA_decision=denied: 10.53%
#
# Loan_amount: 97000
#  BankA_decision=success: 78.95%
#  BankA_decision=denied: 21.05%
#
# Loan_amount: 195000
#  BankA_decision=success: 68.42%
#  BankA_decision=denied: 26.32%
#  BankA_decision=error: 5.26%
#
# Loan_amount: 158000
#  BankA_decision=success: 77.27%
#  BankA_decision=denied: 22.73%
#
# Loan_amount: 109000
#  BankA_decision=success: 85.71%
#  BankA_decision=denied: 14.29%
#
# Loan_amount: 35000
#  BankA_decision=success: 84.44%
#  BankA_decision=denied: 13.33%
#  BankA_decision=error: 2.22%
#
# Loan_amount: 40000
#  BankA_decision=success: 80.39%
#  BankA_decision=denied: 17.65%
#  BankA_decision=error: 1.96%
#
# Loan_amount: 5000
#  BankA_decision=success: 55.88%
#  BankA_decision=denied: 38.24%
#  BankA_decision=error: 5.88%
#
# Loan_amount: 61000
#  BankA_decision=success: 69.39%
#  BankA_decision=denied: 30.61%
#
# Loan_amount: 25000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 26.53%
#  BankA_decision=error: 2.04%
#
# Loan_amount: 93000
#  BankA_decision=success: 68.75%
#  BankA_decision=denied: 27.08%
#  BankA_decision=error: 4.17%
#
# Loan_amount: 167000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 28.57%
#
# Loan_amount: 9000
#  BankA_decision=success: 82.81%
#  BankA_decision=denied: 17.19%
#
# Loan_amount: 24000
#  BankA_decision=success: 79.69%
#  BankA_decision=denied: 18.75%
#  BankA_decision=error: 1.56%
#
# Loan_amount: 66000
#  BankA_decision=success: 70.18%
#  BankA_decision=denied: 28.07%
#  BankA_decision=error: 1.75%
#
# Loan_amount: 183000
#  BankA_decision=success: 68.42%
#  BankA_decision=denied: 31.58%
#
# Loan_amount: 68000
#  BankA_decision=success: 70.45%
#  BankA_decision=denied: 25.00%
#  BankA_decision=error: 4.55%
#
# Loan_amount: 23000
#  BankA_decision=success: 73.77%
#  BankA_decision=denied: 26.23%
#
# Loan_amount: 163000
#  BankA_decision=success: 77.78%
#  BankA_decision=error: 11.11%
#  BankA_decision=denied: 11.11%
#
# Loan_amount: 56000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 28.57%
#
# Loan_amount: 84000
#  BankA_decision=success: 77.08%
#  BankA_decision=denied: 18.75%
#  BankA_decision=error: 4.17%
#
# Loan_amount: 52000
#  BankA_decision=success: 69.64%
#  BankA_decision=denied: 30.36%
#
# Loan_amount: 100000
#  BankA_decision=success: 66.04%
#  BankA_decision=denied: 33.96%
#
# Loan_amount: 136000
#  BankA_decision=success: 53.85%
#  BankA_decision=denied: 46.15%
#
# Loan_amount: 7000
#  BankA_decision=success: 77.27%
#  BankA_decision=denied: 22.73%
#
# Loan_amount: 73000
#  BankA_decision=success: 73.33%
#  BankA_decision=denied: 26.67%
#
# Loan_amount: 143000
#  BankA_decision=success: 64.71%
#  BankA_decision=denied: 35.29%
#
# Loan_amount: 121000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 29.41%
#
# Loan_amount: 107000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 29.41%
#
# Loan_amount: 20000
#  BankA_decision=success: 83.64%
#  BankA_decision=denied: 16.36%
#
# Loan_amount: 6000
#  BankA_decision=success: 61.29%
#  BankA_decision=denied: 35.48%
#  BankA_decision=error: 3.23%
#
# Loan_amount: 120000
#  BankA_decision=success: 65.00%
#  BankA_decision=denied: 35.00%
#
# Loan_amount: 162000
#  BankA_decision=success: 88.24%
#  BankA_decision=denied: 11.76%
#
# Loan_amount: 129000
#  BankA_decision=success: 66.67%
#  BankA_decision=denied: 26.67%
#  BankA_decision=error: 6.67%
#
# Loan_amount: 85000
#  BankA_decision=success: 67.44%
#  BankA_decision=denied: 30.23%
#  BankA_decision=error: 2.33%
#
# Loan_amount: 131000
#  BankA_decision=success: 85.71%
#  BankA_decision=denied: 14.29%
#
# Loan_amount: 32000
#  BankA_decision=success: 85.25%
#  BankA_decision=denied: 14.75%
#
# Loan_amount: 39000
#  BankA_decision=success: 77.78%
#  BankA_decision=denied: 22.22%
#
# Loan_amount: 182000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 112000
#  BankA_decision=success: 58.82%
#  BankA_decision=denied: 41.18%
#
# Loan_amount: 166000
#  BankA_decision=success: 72.73%
#  BankA_decision=denied: 27.27%
#
# Loan_amount: 98000
#  BankA_decision=success: 79.17%
#  BankA_decision=denied: 20.83%
#
# Loan_amount: 115000
#  BankA_decision=success: 68.18%
#  BankA_decision=denied: 31.82%
#
# Loan_amount: 146000
#  BankA_decision=success: 76.92%
#  BankA_decision=denied: 23.08%
#
# Loan_amount: 111000
#  BankA_decision=success: 72.73%
#  BankA_decision=denied: 27.27%
#
# Loan_amount: 199000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 20.00%
#
# Loan_amount: 54000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 16.67%
#
# Loan_amount: 69000
#  BankA_decision=success: 79.55%
#  BankA_decision=denied: 20.45%
#
# Loan_amount: 150000
#  BankA_decision=success: 78.57%
#  BankA_decision=denied: 21.43%
#
# Loan_amount: 101000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 12.50%
#  BankA_decision=error: 6.25%
#
# Loan_amount: 63000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 18.75%
#
# Loan_amount: 44000
#  BankA_decision=success: 64.00%
#  BankA_decision=denied: 34.00%
#  BankA_decision=error: 2.00%
#
# Loan_amount: 154000
#  BankA_decision=denied: 52.94%
#  BankA_decision=success: 47.06%
#
# Loan_amount: 170000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 149000
#  BankA_decision=success: 90.91%
#  BankA_decision=denied: 9.09%
#
# Loan_amount: 192000
#  BankA_decision=success: 64.71%
#  BankA_decision=denied: 35.29%
#
# Loan_amount: 37000
#  BankA_decision=success: 58.70%
#  BankA_decision=denied: 41.30%
#
# Loan_amount: 164000
#  BankA_decision=success: 70.00%
#  BankA_decision=denied: 30.00%
#
# Loan_amount: 103000
#  BankA_decision=success: 69.23%
#  BankA_decision=denied: 30.77%
#
# Loan_amount: 193000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 18.75%
#
# Loan_amount: 168000
#  BankA_decision=success: 77.78%
#  BankA_decision=denied: 22.22%
#
# Loan_amount: 197000
#  BankA_decision=success: 68.75%
#  BankA_decision=denied: 31.25%
#
# Loan_amount: 178000
#  BankA_decision=success: 56.25%
#  BankA_decision=denied: 43.75%
#
# Loan_amount: 122000
#  BankA_decision=success: 69.23%
#  BankA_decision=denied: 30.77%
#
# Loan_amount: 155000
#  BankA_decision=success: 87.50%
#  BankA_decision=denied: 12.50%
#
# Loan_amount: 130000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 15.00%
#  BankA_decision=error: 5.00%
#
# Loan_amount: 190000
#  BankA_decision=success: 78.57%
#  BankA_decision=denied: 21.43%
#
# Loan_amount: 148000
#  BankA_decision=success: 77.78%
#  BankA_decision=denied: 22.22%
#
# Loan_amount: 134000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 18.75%
#
# Loan_amount: 173000
#  BankA_decision=success: 88.89%
#  BankA_decision=denied: 11.11%
#
# Loan_amount: 196000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 13.33%
#  BankA_decision=error: 6.67%
#
# Loan_amount: 51000
#  BankA_decision=success: 79.07%
#  BankA_decision=denied: 18.60%
#  BankA_decision=error: 2.33%
#
# Loan_amount: 187000
#  BankA_decision=success: 71.43%
#  BankA_decision=denied: 23.81%
#  BankA_decision=error: 4.76%
#
# Loan_amount: 113000
#  BankA_decision=success: 64.71%
#  BankA_decision=denied: 35.29%
#
# Loan_amount: 126000
#  BankA_decision=success: 88.89%
#  BankA_decision=denied: 11.11%
#
# Loan_amount: 142000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 23.53%
#  BankA_decision=error: 5.88%
#
# Loan_amount: 160000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 117000
#  BankA_decision=success: 84.21%
#  BankA_decision=denied: 10.53%
#  BankA_decision=error: 5.26%
#
# Loan_amount: 169000
#  BankA_decision=success: 81.25%
#  BankA_decision=denied: 12.50%
#  BankA_decision=error: 6.25%
#
# Loan_amount: 159000
#  BankA_decision=success: 75.00%
#  BankA_decision=denied: 25.00%
#
# Loan_amount: 185000
#  BankA_decision=success: 73.68%
#  BankA_decision=denied: 26.32%
#
# Loan_amount: 157000
#  BankA_decision=success: 70.59%
#  BankA_decision=denied: 29.41%
#
# Loan_amount: 127000
#  BankA_decision=success: 50.00%
#  BankA_decision=denied: 42.86%
#  BankA_decision=error: 7.14%
#
# Loan_amount: 124000
#  BankA_decision=success: 58.82%
#  BankA_decision=denied: 41.18%
#
# Loan_amount: 102000
#  BankA_decision=success: 78.57%
#  BankA_decision=denied: 21.43%
#
# Loan_amount: 180000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 20.00%
#
# Loan_amount: 181000
#  BankA_decision=success: 83.33%
#  BankA_decision=denied: 16.67%
#
# Loan_amount: 118000
#  BankA_decision=success: 80.00%
#  BankA_decision=denied: 20.00%
#
# Loan_amount: 188000
#  BankA_decision=success: 81.82%
#  BankA_decision=denied: 18.18%
#
# Loan_amount: 176000
#  BankA_decision=success: 100.00%
#
# Loan_amount: 189000
#  BankA_decision=success: 85.00%
#  BankA_decision=denied: 15.00%
#
# Loan_amount: 137000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 33000
#  BankB_decision=success: 71.70%
#  BankB_decision=denied: 28.30%
#
# Loan_amount: 165000
#  BankB_decision=success: 53.85%
#  BankB_decision=denied: 46.15%
#
# Loan_amount: 67000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 23.08%
#  BankB_decision=error: 1.92%
#
# Loan_amount: 36000
#  BankB_decision=success: 79.25%
#  BankB_decision=denied: 18.87%
#  BankB_decision=error: 1.89%
#
# Loan_amount: 47000
#  BankB_decision=success: 72.06%
#  BankB_decision=denied: 26.47%
#  BankB_decision=error: 1.47%
#
# Loan_amount: 175000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 74000
#  BankB_decision=success: 80.30%
#  BankB_decision=denied: 19.70%
#
# Loan_amount: 82000
#  BankB_decision=success: 86.96%
#  BankB_decision=denied: 13.04%
#
# Loan_amount: 171000
#  BankB_decision=success: 70.00%
#  BankB_decision=denied: 30.00%
#
# Loan_amount: 72000
#  BankB_decision=success: 86.79%
#  BankB_decision=denied: 13.21%
#
# Loan_amount: 57000
#  BankB_decision=success: 81.25%
#  BankB_decision=denied: 18.75%
#
# Loan_amount: 119000
#  BankB_decision=success: 88.89%
#  BankB_decision=denied: 11.11%
#
# Loan_amount: 138000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 92000
#  BankB_decision=success: 78.72%
#  BankB_decision=denied: 21.28%
#
# Loan_amount: 34000
#  BankB_decision=success: 67.86%
#  BankB_decision=denied: 30.36%
#  BankB_decision=error: 1.79%
#
# Loan_amount: 110000
#  BankB_decision=success: 85.00%
#  BankB_decision=denied: 15.00%
#
# Loan_amount: 4000
#  BankB_decision=success: 86.21%
#  BankB_decision=denied: 13.79%
#
# Loan_amount: 16000
#  BankB_decision=success: 77.05%
#  BankB_decision=denied: 22.95%
#
# Loan_amount: 31000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 21.15%
#  BankB_decision=error: 3.85%
#
# Loan_amount: 62000
#  BankB_decision=success: 73.08%
#  BankB_decision=denied: 23.08%
#  BankB_decision=error: 3.85%
#
# Loan_amount: 70000
#  BankB_decision=success: 72.50%
#  BankB_decision=denied: 27.50%
#
# Loan_amount: 186000
#  BankB_decision=success: 85.71%
#  BankB_decision=error: 7.14%
#  BankB_decision=denied: 7.14%
#
# Loan_amount: 133000
#  BankB_decision=success: 57.14%
#  BankB_decision=denied: 42.86%
#
# Loan_amount: 14000
#  BankB_decision=success: 74.07%
#  BankB_decision=denied: 24.07%
#  BankB_decision=error: 1.85%
#
# Loan_amount: 161000
#  BankB_decision=success: 83.33%
#  BankB_decision=denied: 16.67%
#
# Loan_amount: 64000
#  BankB_decision=success: 70.83%
#  BankB_decision=denied: 29.17%
#
# Loan_amount: 12000
#  BankB_decision=success: 72.73%
#  BankB_decision=denied: 27.27%
#
# Loan_amount: 13000
#  BankB_decision=success: 74.51%
#  BankB_decision=denied: 25.49%
#
# Loan_amount: 153000
#  BankB_decision=success: 57.89%
#  BankB_decision=denied: 31.58%
#  BankB_decision=error: 10.53%
#
# Loan_amount: 83000
#  BankB_decision=success: 72.09%
#  BankB_decision=denied: 27.91%
#
# Loan_amount: 42000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 23.33%
#  BankB_decision=error: 1.67%
#
# Loan_amount: 76000
#  BankB_decision=success: 72.34%
#  BankB_decision=denied: 25.53%
#  BankB_decision=error: 2.13%
#
# Loan_amount: 26000
#  BankB_decision=success: 71.19%
#  BankB_decision=denied: 28.81%
#
# Loan_amount: 123000
#  BankB_decision=success: 64.71%
#  BankB_decision=denied: 35.29%
#
# Loan_amount: 41000
#  BankB_decision=success: 72.55%
#  BankB_decision=denied: 27.45%
#
# Loan_amount: 108000
#  BankB_decision=success: 57.89%
#  BankB_decision=denied: 42.11%
#
# Loan_amount: 38000
#  BankB_decision=success: 55.81%
#  BankB_decision=denied: 44.19%
#
# Loan_amount: 79000
#  BankB_decision=success: 77.55%
#  BankB_decision=denied: 22.45%
#
# Loan_amount: 174000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 65000
#  BankB_decision=success: 68.89%
#  BankB_decision=denied: 28.89%
#  BankB_decision=error: 2.22%
#
# Loan_amount: 95000
#  BankB_decision=success: 61.02%
#  BankB_decision=denied: 37.29%
#  BankB_decision=error: 1.69%
#
# Loan_amount: 184000
#  BankB_decision=success: 78.95%
#  BankB_decision=denied: 21.05%
#
# Loan_amount: 80000
#  BankB_decision=success: 73.68%
#  BankB_decision=denied: 26.32%
#
# Loan_amount: 19000
#  BankB_decision=success: 74.42%
#  BankB_decision=denied: 25.58%
#
# Loan_amount: 87000
#  BankB_decision=success: 80.33%
#  BankB_decision=denied: 14.75%
#  BankB_decision=error: 4.92%
#
# Loan_amount: 139000
#  BankB_decision=success: 76.47%
#  BankB_decision=denied: 23.53%
#
# Loan_amount: 198000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 20.00%
#  BankB_decision=error: 5.00%
#
# Loan_amount: 145000
#  BankB_decision=success: 73.68%
#  BankB_decision=denied: 26.32%
#
# Loan_amount: 125000
#  BankB_decision=success: 90.48%
#  BankB_decision=error: 4.76%
#  BankB_decision=denied: 4.76%
#
# Loan_amount: 46000
#  BankB_decision=success: 75.56%
#  BankB_decision=denied: 22.22%
#  BankB_decision=error: 2.22%
#
# Loan_amount: 90000
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Loan_amount: 17000
#  BankB_decision=success: 73.21%
#  BankB_decision=denied: 26.79%
#
# Loan_amount: 27000
#  BankB_decision=success: 73.44%
#  BankB_decision=denied: 25.00%
#  BankB_decision=error: 1.56%
#
# Loan_amount: 86000
#  BankB_decision=success: 60.47%
#  BankB_decision=denied: 37.21%
#  BankB_decision=error: 2.33%
#
# Loan_amount: 71000
#  BankB_decision=success: 65.22%
#  BankB_decision=denied: 30.43%
#  BankB_decision=error: 4.35%
#
# Loan_amount: 194000
#  BankB_decision=success: 80.00%
#  BankB_decision=denied: 20.00%
#
# Loan_amount: 50000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 48000
#  BankB_decision=success: 81.48%
#  BankB_decision=denied: 18.52%
#
# Loan_amount: 177000
#  BankB_decision=success: 86.67%
#  BankB_decision=denied: 13.33%
#
# Loan_amount: 89000
#  BankB_decision=success: 79.17%
#  BankB_decision=denied: 16.67%
#  BankB_decision=error: 4.17%
#
# Loan_amount: 45000
#  BankB_decision=success: 65.22%
#  BankB_decision=denied: 32.61%
#  BankB_decision=error: 2.17%
#
# Loan_amount: 53000
#  BankB_decision=success: 86.79%
#  BankB_decision=denied: 11.32%
#  BankB_decision=error: 1.89%
#
# Loan_amount: 144000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 60000
#  BankB_decision=success: 73.47%
#  BankB_decision=denied: 26.53%
#
# Loan_amount: 78000
#  BankB_decision=success: 74.47%
#  BankB_decision=denied: 23.40%
#  BankB_decision=error: 2.13%
#
# Loan_amount: 200000
#  BankB_decision=success: 52.94%
#  BankB_decision=denied: 47.06%
#
# Loan_amount: 18000
#  BankB_decision=success: 68.75%
#  BankB_decision=denied: 29.17%
#  BankB_decision=error: 2.08%
#
# Loan_amount: 58000
#  BankB_decision=success: 71.79%
#  BankB_decision=denied: 28.21%
#
# Loan_amount: 43000
#  BankB_decision=success: 70.49%
#  BankB_decision=denied: 27.87%
#  BankB_decision=error: 1.64%
#
# Loan_amount: 21000
#  BankB_decision=success: 65.45%
#  BankB_decision=denied: 34.55%
#
# Loan_amount: 55000
#  BankB_decision=success: 86.67%
#  BankB_decision=denied: 13.33%
#
# Loan_amount: 29000
#  BankB_decision=success: 83.33%
#  BankB_decision=denied: 15.00%
#  BankB_decision=error: 1.67%
#
# Loan_amount: 88000
#  BankB_decision=success: 64.71%
#  BankB_decision=denied: 35.29%
#
# Loan_amount: 116000
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Loan_amount: 8000
#  BankB_decision=success: 67.92%
#  BankB_decision=denied: 32.08%
#
# Loan_amount: 152000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 18.75%
#  BankB_decision=error: 6.25%
#
# Loan_amount: 156000
#  BankB_decision=success: 86.36%
#  BankB_decision=denied: 9.09%
#  BankB_decision=error: 4.55%
#
# Loan_amount: 30000
#  BankB_decision=success: 68.75%
#  BankB_decision=denied: 27.08%
#  BankB_decision=error: 4.17%
#
# Loan_amount: 77000
#  BankB_decision=success: 66.00%
#  BankB_decision=denied: 34.00%
#
# Loan_amount: 104000
#  BankB_decision=success: 90.00%
#  BankB_decision=denied: 10.00%
#
# Loan_amount: 91000
#  BankB_decision=success: 77.55%
#  BankB_decision=denied: 22.45%
#
# Loan_amount: 15000
#  BankB_decision=success: 80.49%
#  BankB_decision=denied: 19.51%
#
# Loan_amount: 172000
#  BankB_decision=success: 57.14%
#  BankB_decision=denied: 35.71%
#  BankB_decision=error: 7.14%
#
# Loan_amount: 99000
#  BankB_decision=success: 77.78%
#  BankB_decision=denied: 20.00%
#  BankB_decision=error: 2.22%
#
# Loan_amount: 59000
#  BankB_decision=success: 70.83%
#  BankB_decision=denied: 27.08%
#  BankB_decision=error: 2.08%
#
# Loan_amount: 81000
#  BankB_decision=success: 82.26%
#  BankB_decision=denied: 17.74%
#
# Loan_amount: 22000
#  BankB_decision=success: 72.09%
#  BankB_decision=denied: 27.91%
#
# Loan_amount: 141000
#  BankB_decision=success: 82.35%
#  BankB_decision=denied: 17.65%
#
# Loan_amount: 105000
#  BankB_decision=success: 77.78%
#  BankB_decision=denied: 18.52%
#  BankB_decision=error: 3.70%
#
# Loan_amount: 75000
#  BankB_decision=success: 67.39%
#  BankB_decision=denied: 30.43%
#  BankB_decision=error: 2.17%
#
# Loan_amount: 191000
#  BankB_decision=success: 82.61%
#  BankB_decision=denied: 17.39%
#
# Loan_amount: 179000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 11000
#  BankB_decision=success: 64.44%
#  BankB_decision=denied: 35.56%
#
# Loan_amount: 49000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 22.73%
#  BankB_decision=error: 2.27%
#
# Loan_amount: 147000
#  BankB_decision=success: 83.33%
#  BankB_decision=denied: 16.67%
#
# Loan_amount: 28000
#  BankB_decision=success: 82.35%
#  BankB_decision=denied: 17.65%
#
# Loan_amount: 140000
#  BankB_decision=success: 76.92%
#  BankB_decision=denied: 15.38%
#  BankB_decision=error: 7.69%
#
# Loan_amount: 135000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 132000
#  BankB_decision=success: 71.43%
#  BankB_decision=denied: 28.57%
#
# Loan_amount: 151000
#  BankB_decision=success: 78.26%
#  BankB_decision=denied: 17.39%
#  BankB_decision=error: 4.35%
#
# Loan_amount: 128000
#  BankB_decision=success: 87.50%
#  BankB_decision=denied: 12.50%
#
# Loan_amount: 94000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 23.08%
#  BankB_decision=error: 1.92%
#
# Loan_amount: 96000
#  BankB_decision=success: 85.42%
#  BankB_decision=denied: 14.58%
#
# Loan_amount: 10000
#  BankB_decision=success: 74.55%
#  BankB_decision=denied: 21.82%
#  BankB_decision=error: 3.64%
#
# Loan_amount: 114000
#  BankB_decision=success: 81.25%
#  BankB_decision=denied: 18.75%
#
# Loan_amount: 106000
#  BankB_decision=success: 89.47%
#  BankB_decision=denied: 10.53%
#
# Loan_amount: 97000
#  BankB_decision=success: 84.21%
#  BankB_decision=denied: 15.79%
#
# Loan_amount: 195000
#  BankB_decision=success: 73.68%
#  BankB_decision=denied: 26.32%
#
# Loan_amount: 158000
#  BankB_decision=success: 68.18%
#  BankB_decision=denied: 22.73%
#  BankB_decision=error: 9.09%
#
# Loan_amount: 109000
#  BankB_decision=success: 71.43%
#  BankB_decision=denied: 28.57%
#
# Loan_amount: 35000
#  BankB_decision=success: 80.00%
#  BankB_decision=denied: 20.00%
#
# Loan_amount: 40000
#  BankB_decision=success: 76.47%
#  BankB_decision=denied: 23.53%
#
# Loan_amount: 5000
#  BankB_decision=success: 85.29%
#  BankB_decision=denied: 14.71%
#
# Loan_amount: 61000
#  BankB_decision=success: 75.51%
#  BankB_decision=denied: 24.49%
#
# Loan_amount: 25000
#  BankB_decision=success: 81.63%
#  BankB_decision=denied: 16.33%
#  BankB_decision=error: 2.04%
#
# Loan_amount: 93000
#  BankB_decision=success: 72.92%
#  BankB_decision=denied: 27.08%
#
# Loan_amount: 167000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 9000
#  BankB_decision=success: 73.44%
#  BankB_decision=denied: 25.00%
#  BankB_decision=error: 1.56%
#
# Loan_amount: 24000
#  BankB_decision=success: 71.88%
#  BankB_decision=denied: 23.44%
#  BankB_decision=error: 4.69%
#
# Loan_amount: 66000
#  BankB_decision=success: 75.44%
#  BankB_decision=denied: 24.56%
#
# Loan_amount: 183000
#  BankB_decision=success: 68.42%
#  BankB_decision=denied: 31.58%
#
# Loan_amount: 68000
#  BankB_decision=success: 72.73%
#  BankB_decision=denied: 22.73%
#  BankB_decision=error: 4.55%
#
# Loan_amount: 23000
#  BankB_decision=success: 68.85%
#  BankB_decision=denied: 29.51%
#  BankB_decision=error: 1.64%
#
# Loan_amount: 163000
#  BankB_decision=success: 100.00%
#
# Loan_amount: 56000
#  BankB_decision=success: 68.57%
#  BankB_decision=denied: 31.43%
#
# Loan_amount: 84000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 22.92%
#  BankB_decision=error: 2.08%
#
# Loan_amount: 52000
#  BankB_decision=success: 66.07%
#  BankB_decision=denied: 30.36%
#  BankB_decision=error: 3.57%
#
# Loan_amount: 100000
#  BankB_decision=success: 73.58%
#  BankB_decision=denied: 24.53%
#  BankB_decision=error: 1.89%
#
# Loan_amount: 136000
#  BankB_decision=success: 61.54%
#  BankB_decision=denied: 38.46%
#
# Loan_amount: 7000
#  BankB_decision=success: 86.36%
#  BankB_decision=denied: 13.64%
#
# Loan_amount: 73000
#  BankB_decision=success: 77.78%
#  BankB_decision=denied: 22.22%
#
# Loan_amount: 143000
#  BankB_decision=success: 70.59%
#  BankB_decision=denied: 29.41%
#
# Loan_amount: 121000
#  BankB_decision=success: 70.59%
#  BankB_decision=denied: 29.41%
#
# Loan_amount: 107000
#  BankB_decision=success: 64.71%
#  BankB_decision=denied: 35.29%
#
# Loan_amount: 20000
#  BankB_decision=success: 78.18%
#  BankB_decision=denied: 21.82%
#
# Loan_amount: 6000
#  BankB_decision=success: 83.87%
#  BankB_decision=denied: 16.13%
#
# Loan_amount: 120000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 162000
#  BankB_decision=success: 58.82%
#  BankB_decision=denied: 41.18%
#
# Loan_amount: 129000
#  BankB_decision=success: 80.00%
#  BankB_decision=denied: 20.00%
#
# Loan_amount: 85000
#  BankB_decision=success: 62.79%
#  BankB_decision=denied: 34.88%
#  BankB_decision=error: 2.33%
#
# Loan_amount: 131000
#  BankB_decision=success: 57.14%
#  BankB_decision=denied: 42.86%
#
# Loan_amount: 32000
#  BankB_decision=success: 77.05%
#  BankB_decision=denied: 22.95%
#
# Loan_amount: 39000
#  BankB_decision=success: 68.52%
#  BankB_decision=denied: 29.63%
#  BankB_decision=error: 1.85%
#
# Loan_amount: 182000
#  BankB_decision=success: 56.25%
#  BankB_decision=denied: 43.75%
#
# Loan_amount: 112000
#  BankB_decision=success: 82.35%
#  BankB_decision=denied: 17.65%
#
# Loan_amount: 166000
#  BankB_decision=success: 81.82%
#  BankB_decision=denied: 18.18%
#
# Loan_amount: 98000
#  BankB_decision=success: 79.17%
#  BankB_decision=denied: 20.83%
#
# Loan_amount: 115000
#  BankB_decision=success: 59.09%
#  BankB_decision=denied: 40.91%
#
# Loan_amount: 146000
#  BankB_decision=success: 69.23%
#  BankB_decision=denied: 30.77%
#
# Loan_amount: 111000
#  BankB_decision=success: 72.73%
#  BankB_decision=denied: 27.27%
#
# Loan_amount: 199000
#  BankB_decision=success: 70.00%
#  BankB_decision=denied: 25.00%
#  BankB_decision=error: 5.00%
#
# Loan_amount: 54000
#  BankB_decision=success: 68.75%
#  BankB_decision=denied: 29.17%
#  BankB_decision=error: 2.08%
#
# Loan_amount: 69000
#  BankB_decision=success: 79.55%
#  BankB_decision=denied: 20.45%
#
# Loan_amount: 150000
#  BankB_decision=success: 57.14%
#  BankB_decision=denied: 42.86%
#
# Loan_amount: 101000
#  BankB_decision=success: 100.00%
#
# Loan_amount: 63000
#  BankB_decision=success: 77.08%
#  BankB_decision=denied: 22.92%
#
# Loan_amount: 44000
#  BankB_decision=success: 78.00%
#  BankB_decision=denied: 22.00%
#
# Loan_amount: 154000
#  BankB_decision=success: 58.82%
#  BankB_decision=denied: 41.18%
#
# Loan_amount: 170000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 149000
#  BankB_decision=success: 90.91%
#  BankB_decision=denied: 9.09%
#
# Loan_amount: 192000
#  BankB_decision=success: 58.82%
#  BankB_decision=denied: 35.29%
#  BankB_decision=error: 5.88%
#
# Loan_amount: 37000
#  BankB_decision=success: 69.57%
#  BankB_decision=denied: 28.26%
#  BankB_decision=error: 2.17%
#
# Loan_amount: 164000
#  BankB_decision=success: 70.00%
#  BankB_decision=denied: 30.00%
#
# Loan_amount: 103000
#  BankB_decision=success: 76.92%
#  BankB_decision=denied: 23.08%
#
# Loan_amount: 193000
#  BankB_decision=success: 62.50%
#  BankB_decision=denied: 31.25%
#  BankB_decision=error: 6.25%
#
# Loan_amount: 168000
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Loan_amount: 197000
#  BankB_decision=success: 56.25%
#  BankB_decision=denied: 43.75%
#
# Loan_amount: 178000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 122000
#  BankB_decision=success: 84.62%
#  BankB_decision=denied: 15.38%
#
# Loan_amount: 155000
#  BankB_decision=success: 62.50%
#  BankB_decision=denied: 25.00%
#  BankB_decision=error: 12.50%
#
# Loan_amount: 130000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 25.00%
#
# Loan_amount: 190000
#  BankB_decision=success: 64.29%
#  BankB_decision=denied: 35.71%
#
# Loan_amount: 148000
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Loan_amount: 134000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 18.75%
#  BankB_decision=error: 6.25%
#
# Loan_amount: 173000
#  BankB_decision=success: 88.89%
#  BankB_decision=denied: 11.11%
#
# Loan_amount: 196000
#  BankB_decision=success: 73.33%
#  BankB_decision=denied: 26.67%
#
# Loan_amount: 51000
#  BankB_decision=success: 62.79%
#  BankB_decision=denied: 37.21%
#
# Loan_amount: 187000
#  BankB_decision=success: 66.67%
#  BankB_decision=denied: 33.33%
#
# Loan_amount: 113000
#  BankB_decision=success: 88.24%
#  BankB_decision=denied: 11.76%
#
# Loan_amount: 126000
#  BankB_decision=success: 83.33%
#  BankB_decision=denied: 16.67%
#
# Loan_amount: 142000
#  BankB_decision=success: 70.59%
#  BankB_decision=denied: 17.65%
#  BankB_decision=error: 11.76%
#
# Loan_amount: 160000
#  BankB_decision=success: 93.75%
#  BankB_decision=denied: 6.25%
#
# Loan_amount: 117000
#  BankB_decision=success: 78.95%
#  BankB_decision=denied: 21.05%
#
# Loan_amount: 169000
#  BankB_decision=success: 56.25%
#  BankB_decision=denied: 43.75%
#
# Loan_amount: 159000
#  BankB_decision=success: 62.50%
#  BankB_decision=denied: 37.50%
#
# Loan_amount: 185000
#  BankB_decision=success: 73.68%
#  BankB_decision=denied: 26.32%
#
# Loan_amount: 157000
#  BankB_decision=success: 64.71%
#  BankB_decision=denied: 35.29%
#
# Loan_amount: 127000
#  BankB_decision=success: 85.71%
#  BankB_decision=denied: 14.29%
#
# Loan_amount: 124000
#  BankB_decision=success: 82.35%
#  BankB_decision=denied: 17.65%
#
# Loan_amount: 102000
#  BankB_decision=success: 78.57%
#  BankB_decision=denied: 21.43%
#
# Loan_amount: 180000
#  BankB_decision=success: 86.67%
#  BankB_decision=denied: 13.33%
#
# Loan_amount: 181000
#  BankB_decision=success: 61.11%
#  BankB_decision=denied: 38.89%
#
# Loan_amount: 118000
#  BankB_decision=success: 93.33%
#  BankB_decision=denied: 6.67%
#
# Loan_amount: 188000
#  BankB_decision=success: 54.55%
#  BankB_decision=denied: 45.45%
#
# Loan_amount: 176000
#  BankB_decision=success: 72.73%
#  BankB_decision=denied: 27.27%
#
# Loan_amount: 189000
#  BankB_decision=success: 75.00%
#  BankB_decision=denied: 20.00%
#  BankB_decision=error: 5.00%
#
# Loan_amount: 137000
#  BankC_decision=success: 85.71%
#  BankC_decision=denied: 14.29%
#
# Loan_amount: 33000
#  BankC_decision=success: 84.91%
#  BankC_decision=denied: 15.09%
#
# Loan_amount: 165000
#  BankC_decision=success: 100.00%
#
# Loan_amount: 67000
#  BankC_decision=success: 73.08%
#  BankC_decision=denied: 26.92%
#
# Loan_amount: 36000
#  BankC_decision=success: 71.70%
#  BankC_decision=denied: 28.30%
#
# Loan_amount: 47000
#  BankC_decision=success: 86.76%
#  BankC_decision=denied: 13.24%
#
# Loan_amount: 175000
#  BankC_decision=success: 85.00%
#  BankC_decision=denied: 15.00%
#
# Loan_amount: 74000
#  BankC_decision=success: 77.27%
#  BankC_decision=denied: 21.21%
#  BankC_decision=error: 1.52%
#
# Loan_amount: 82000
#  BankC_decision=success: 80.43%
#  BankC_decision=denied: 19.57%
#
# Loan_amount: 171000
#  BankC_decision=success: 60.00%
#  BankC_decision=denied: 30.00%
#  BankC_decision=error: 10.00%
#
# Loan_amount: 72000
#  BankC_decision=success: 71.70%
# ...
#  BankE_decision=denied: 26.09%
#
# Loan_amount: 191000
#  BankE_decision=success: 69.57%
#  BankE_decision=denied: 26.09%
#  BankE_decision=error: 4.35%
#
# Loan_amount: 179000
#  BankE_decision=success: 71.43%
#  BankE_decision=denied: 28.57%
#
# Loan_amount: 11000
#  BankE_decision=success: 77.78%
#  BankE_decision=denied: 22.22%
#
# Loan_amount: 49000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 147000
#  BankE_decision=success: 83.33%
#  BankE_decision=denied: 16.67%
#
# Loan_amount: 28000
#  BankE_decision=success: 68.63%
#  BankE_decision=denied: 29.41%
#  BankE_decision=error: 1.96%
#
# Loan_amount: 140000
#  BankE_decision=success: 69.23%
#  BankE_decision=denied: 30.77%
#
# Loan_amount: 135000
#  BankE_decision=success: 78.57%
#  BankE_decision=denied: 21.43%
#
# Loan_amount: 132000
#  BankE_decision=success: 57.14%
#  BankE_decision=denied: 35.71%
#  BankE_decision=error: 7.14%
#
# Loan_amount: 151000
#  BankE_decision=success: 60.87%
#  BankE_decision=denied: 39.13%
#
# Loan_amount: 128000
#  BankE_decision=success: 50.00%
#  BankE_decision=denied: 37.50%
#  BankE_decision=error: 12.50%
#
# Loan_amount: 94000
#  BankE_decision=success: 82.69%
#  BankE_decision=denied: 17.31%
#
# Loan_amount: 96000
#  BankE_decision=success: 70.83%
#  BankE_decision=denied: 25.00%
#  BankE_decision=error: 4.17%
#
# Loan_amount: 10000
#  BankE_decision=success: 81.82%
#  BankE_decision=denied: 18.18%
#
# Loan_amount: 114000
#  BankE_decision=success: 68.75%
#  BankE_decision=denied: 31.25%
#
# Loan_amount: 106000
#  BankE_decision=success: 68.42%
#  BankE_decision=denied: 31.58%
#
# Loan_amount: 97000
#  BankE_decision=success: 75.44%
#  BankE_decision=denied: 21.05%
#  BankE_decision=error: 3.51%
#
# Loan_amount: 195000
#  BankE_decision=success: 78.95%
#  BankE_decision=denied: 15.79%
#  BankE_decision=error: 5.26%
#
# Loan_amount: 158000
#  BankE_decision=success: 81.82%
#  BankE_decision=denied: 18.18%
#
# Loan_amount: 109000
#  BankE_decision=success: 64.29%
#  BankE_decision=denied: 35.71%
#
# Loan_amount: 35000
#  BankE_decision=success: 80.00%
#  BankE_decision=denied: 20.00%
#
# Loan_amount: 40000
#  BankE_decision=success: 90.20%
#  BankE_decision=denied: 9.80%
#
# Loan_amount: 5000
#  BankE_decision=success: 76.47%
#  BankE_decision=denied: 23.53%
#
# Loan_amount: 61000
#  BankE_decision=success: 73.47%
#  BankE_decision=denied: 22.45%
#  BankE_decision=error: 4.08%
#
# Loan_amount: 25000
#  BankE_decision=success: 77.55%
#  BankE_decision=denied: 22.45%
#
# Loan_amount: 93000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 167000
#  BankE_decision=success: 85.71%
#  BankE_decision=denied: 14.29%
#
# Loan_amount: 9000
#  BankE_decision=success: 84.38%
#  BankE_decision=denied: 12.50%
#  BankE_decision=error: 3.12%
#
# Loan_amount: 24000
#  BankE_decision=success: 70.31%
#  BankE_decision=denied: 29.69%
#
# Loan_amount: 66000
#  BankE_decision=success: 70.18%
#  BankE_decision=denied: 28.07%
#  BankE_decision=error: 1.75%
#
# Loan_amount: 183000
#  BankE_decision=success: 68.42%
#  BankE_decision=denied: 31.58%
#
# Loan_amount: 68000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 22.73%
#  BankE_decision=error: 2.27%
#
# Loan_amount: 23000
#  BankE_decision=success: 73.77%
#  BankE_decision=denied: 24.59%
#  BankE_decision=error: 1.64%
#
# Loan_amount: 163000
#  BankE_decision=success: 77.78%
#  BankE_decision=denied: 22.22%
#
# Loan_amount: 56000
#  BankE_decision=success: 71.43%
#  BankE_decision=denied: 28.57%
#
# Loan_amount: 84000
#  BankE_decision=success: 81.25%
#  BankE_decision=denied: 14.58%
#  BankE_decision=error: 4.17%
#
# Loan_amount: 52000
#  BankE_decision=success: 71.43%
#  BankE_decision=denied: 25.00%
#  BankE_decision=error: 3.57%
#
# Loan_amount: 100000
#  BankE_decision=success: 79.25%
#  BankE_decision=denied: 20.75%
#
# Loan_amount: 136000
#  BankE_decision=success: 69.23%
#  BankE_decision=denied: 23.08%
#  BankE_decision=error: 7.69%
#
# Loan_amount: 7000
#  BankE_decision=success: 79.55%
#  BankE_decision=denied: 20.45%
#
# Loan_amount: 73000
#  BankE_decision=success: 68.89%
#  BankE_decision=denied: 31.11%
#
# Loan_amount: 143000
#  BankE_decision=success: 88.24%
#  BankE_decision=denied: 11.76%
#
# Loan_amount: 121000
#  BankE_decision=success: 70.59%
#  BankE_decision=denied: 29.41%
#
# Loan_amount: 107000
#  BankE_decision=success: 76.47%
#  BankE_decision=denied: 23.53%
#
# Loan_amount: 20000
#  BankE_decision=success: 72.73%
#  BankE_decision=denied: 27.27%
#
# Loan_amount: 6000
#  BankE_decision=success: 74.19%
#  BankE_decision=denied: 25.81%
#
# Loan_amount: 120000
#  BankE_decision=success: 70.00%
#  BankE_decision=denied: 30.00%
#
# Loan_amount: 162000
#  BankE_decision=success: 82.35%
#  BankE_decision=denied: 17.65%
#
# Loan_amount: 129000
#  BankE_decision=success: 66.67%
#  BankE_decision=denied: 33.33%
#
# Loan_amount: 85000
#  BankE_decision=success: 81.40%
#  BankE_decision=denied: 13.95%
#  BankE_decision=error: 4.65%
#
# Loan_amount: 131000
#  BankE_decision=success: 64.29%
#  BankE_decision=denied: 35.71%
#
# Loan_amount: 32000
#  BankE_decision=success: 75.41%
#  BankE_decision=denied: 22.95%
#  BankE_decision=error: 1.64%
#
# Loan_amount: 39000
#  BankE_decision=success: 74.07%
#  BankE_decision=denied: 24.07%
#  BankE_decision=error: 1.85%
#
# Loan_amount: 182000
#  BankE_decision=success: 81.25%
#  BankE_decision=denied: 12.50%
#  BankE_decision=error: 6.25%
#
# Loan_amount: 112000
#  BankE_decision=success: 88.24%
#  BankE_decision=denied: 11.76%
#
# Loan_amount: 166000
#  BankE_decision=success: 68.18%
#  BankE_decision=denied: 31.82%
#
# Loan_amount: 98000
#  BankE_decision=success: 62.50%
#  BankE_decision=denied: 33.33%
#  BankE_decision=error: 4.17%
#
# Loan_amount: 115000
#  BankE_decision=success: 77.27%
#  BankE_decision=denied: 18.18%
#  BankE_decision=error: 4.55%
#
# Loan_amount: 146000
#  BankE_decision=success: 53.85%
#  BankE_decision=denied: 46.15%
#
# Loan_amount: 111000
#  BankE_decision=success: 63.64%
#  BankE_decision=denied: 36.36%
#
# Loan_amount: 199000
#  BankE_decision=success: 85.00%
#  BankE_decision=denied: 15.00%
#
# Loan_amount: 54000
#  BankE_decision=success: 66.67%
#  BankE_decision=denied: 29.17%
#  BankE_decision=error: 4.17%
#
# Loan_amount: 69000
#  BankE_decision=success: 88.64%
#  BankE_decision=denied: 11.36%
#
# Loan_amount: 150000
#  BankE_decision=success: 57.14%
#  BankE_decision=denied: 42.86%
#
# Loan_amount: 101000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 63000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 44000
#  BankE_decision=success: 86.00%
#  BankE_decision=denied: 14.00%
#
# Loan_amount: 154000
#  BankE_decision=success: 70.59%
#  BankE_decision=denied: 23.53%
#  BankE_decision=error: 5.88%
#
# Loan_amount: 170000
#  BankE_decision=success: 56.25%
#  BankE_decision=denied: 43.75%
#
# Loan_amount: 149000
#  BankE_decision=success: 90.91%
#  BankE_decision=denied: 9.09%
#
# Loan_amount: 192000
#  BankE_decision=success: 82.35%
#  BankE_decision=denied: 17.65%
#
# Loan_amount: 37000
#  BankE_decision=success: 80.43%
#  BankE_decision=denied: 17.39%
#  BankE_decision=error: 2.17%
#
# Loan_amount: 164000
#  BankE_decision=success: 60.00%
#  BankE_decision=denied: 40.00%
#
# Loan_amount: 103000
#  BankE_decision=success: 84.62%
#  BankE_decision=denied: 15.38%
#
# Loan_amount: 193000
#  BankE_decision=success: 87.50%
#  BankE_decision=denied: 12.50%
#
# Loan_amount: 168000
#  BankE_decision=success: 66.67%
#  BankE_decision=denied: 33.33%
#
# Loan_amount: 197000
#  BankE_decision=success: 68.75%
#  BankE_decision=denied: 31.25%
#
# Loan_amount: 178000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 122000
#  BankE_decision=success: 69.23%
#  BankE_decision=denied: 30.77%
#
# Loan_amount: 155000
#  BankE_decision=success: 62.50%
#  BankE_decision=denied: 37.50%
#
# Loan_amount: 130000
#  BankE_decision=success: 80.00%
#  BankE_decision=denied: 20.00%
#
# Loan_amount: 190000
#  BankE_decision=success: 64.29%
#  BankE_decision=denied: 35.71%
#
# Loan_amount: 148000
#  BankE_decision=success: 77.78%
#  BankE_decision=denied: 22.22%
#
# Loan_amount: 134000
#  BankE_decision=success: 87.50%
#  BankE_decision=denied: 12.50%
#
# Loan_amount: 173000
#  BankE_decision=success: 55.56%
#  BankE_decision=denied: 44.44%
#
# Loan_amount: 196000
#  BankE_decision=success: 86.67%
#  BankE_decision=denied: 13.33%
#
# Loan_amount: 51000
#  BankE_decision=success: 83.72%
#  BankE_decision=denied: 16.28%
#
# Loan_amount: 187000
#  BankE_decision=success: 76.19%
#  BankE_decision=denied: 14.29%
#  BankE_decision=error: 9.52%
#
# Loan_amount: 113000
#  BankE_decision=success: 82.35%
#  BankE_decision=denied: 11.76%
#  BankE_decision=error: 5.88%
#
# Loan_amount: 126000
#  BankE_decision=success: 83.33%
#  BankE_decision=denied: 16.67%
#
# Loan_amount: 142000
#  BankE_decision=success: 76.47%
#  BankE_decision=denied: 23.53%
#
# Loan_amount: 160000
#  BankE_decision=success: 56.25%
#  BankE_decision=denied: 43.75%
#
# Loan_amount: 117000
#  BankE_decision=success: 84.21%
#  BankE_decision=denied: 15.79%
#
# Loan_amount: 169000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_amount: 159000
#  BankE_decision=success: 81.25%
#  BankE_decision=denied: 12.50%
#  BankE_decision=error: 6.25%
#
# Loan_amount: 185000
#  BankE_decision=success: 57.89%
#  BankE_decision=denied: 36.84%
#  BankE_decision=error: 5.26%
#
# Loan_amount: 157000
#  BankE_decision=success: 76.47%
#  BankE_decision=denied: 23.53%
#
# Loan_amount: 127000
#  BankE_decision=success: 78.57%
#  BankE_decision=denied: 21.43%
#
# Loan_amount: 124000
#  BankE_decision=success: 64.71%
#  BankE_decision=denied: 35.29%
#
# Loan_amount: 102000
#  BankE_decision=success: 85.71%
#  BankE_decision=denied: 14.29%
#
# Loan_amount: 180000
#  BankE_decision=success: 80.00%
#  BankE_decision=denied: 20.00%
#
# Loan_amount: 181000
#  BankE_decision=success: 77.78%
#  BankE_decision=denied: 22.22%
#
# Loan_amount: 118000
#  BankE_decision=success: 80.00%
#  BankE_decision=denied: 20.00%
#
# Loan_amount: 188000
#  BankE_decision=success: 100.00%
#
# Loan_amount: 176000
#  BankE_decision=success: 72.73%
#  BankE_decision=denied: 27.27%
#
# Loan_amount: 189000
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 25.00%
#
# Loan_term: 18
#  BankA_decision=success: 75.55%
#  BankA_decision=denied: 23.52%
#  BankA_decision=error: 0.93%
#
# Loan_term: 6
#  BankA_decision=success: 75.91%
#  BankA_decision=denied: 23.03%
#  BankA_decision=error: 1.06%
#
# Loan_term: 24
#  BankA_decision=success: 76.37%
#  BankA_decision=denied: 22.89%
#  BankA_decision=error: 0.75%
#
# Loan_term: 12
#  BankA_decision=success: 73.96%
#  BankA_decision=denied: 24.80%
#  BankA_decision=error: 1.23%
#
# Loan_term: 18
#  BankB_decision=success: 76.72%
#  BankB_decision=denied: 22.47%
#  BankB_decision=error: 0.81%
#
# Loan_term: 6
#  BankB_decision=success: 74.09%
#  BankB_decision=denied: 24.81%
#  BankB_decision=error: 1.10%
#
# Loan_term: 24
#  BankB_decision=success: 71.02%
#  BankB_decision=denied: 27.11%
#  BankB_decision=error: 1.87%
#
# Loan_term: 12
#  BankB_decision=success: 74.66%
#  BankB_decision=denied: 24.23%
#  BankB_decision=error: 1.11%
#
# Loan_term: 18
#  BankC_decision=success: 72.53%
#  BankC_decision=denied: 25.84%
#  BankC_decision=error: 1.63%
#
# Loan_term: 6
#  BankC_decision=success: 75.27%
#  BankC_decision=denied: 24.05%
#  BankC_decision=error: 0.68%
#
# Loan_term: 24
#  BankC_decision=success: 75.25%
#  BankC_decision=denied: 23.88%
#  BankC_decision=error: 0.87%
#
# Loan_term: 12
#  BankC_decision=success: 74.87%
#  BankC_decision=denied: 24.19%
#  BankC_decision=error: 0.94%
#
# Loan_term: 18
#  BankD_decision=success: 77.07%
#  BankD_decision=denied: 22.24%
#  BankD_decision=error: 0.70%
#
# Loan_term: 6
#  BankD_decision=success: 74.34%
#  BankD_decision=denied: 24.22%
#  BankD_decision=error: 1.44%
#
# Loan_term: 24
#  BankD_decision=success: 74.50%
#  BankD_decision=denied: 24.63%
#  BankD_decision=error: 0.87%
#
# Loan_term: 12
#  BankD_decision=success: 74.83%
#  BankD_decision=denied: 24.02%
#  BankD_decision=error: 1.15%
#
# Loan_term: 18
#  BankE_decision=success: 74.85%
#  BankE_decision=denied: 24.33%
#  BankE_decision=error: 0.81%
#
# Loan_term: 6
#  BankE_decision=success: 76.20%
#  BankE_decision=denied: 22.87%
#  BankE_decision=error: 0.93%
#
# Loan_term: 24
#  BankE_decision=success: 75.00%
#  BankE_decision=denied: 23.76%
#  BankE_decision=error: 1.24%
#
# Loan_term: 12
#  BankE_decision=success: 73.63%
#  BankE_decision=denied: 25.09%
#  BankE_decision=error: 1.27%
#
# Goods_category: Furniture
#  BankA_decision=success: 73.47%
#  BankA_decision=denied: 25.16%
#  BankA_decision=error: 1.37%
#
# Goods_category: Fitness
#  BankA_decision=success: 74.75%
#  BankA_decision=denied: 24.48%
#  BankA_decision=error: 0.77%
#
# Goods_category: Medical_services
#  BankA_decision=success: 76.09%
#  BankA_decision=denied: 22.83%
#  BankA_decision=error: 1.09%
#
# Goods_category: Education
#  BankA_decision=success: 75.35%
#  BankA_decision=denied: 23.56%
#  BankA_decision=error: 1.09%
#
# Goods_category: Other
#  BankA_decision=success: 76.38%
#  BankA_decision=denied: 22.95%
#  BankA_decision=error: 0.67%
#
# Goods_category: Travel
#  BankA_decision=success: 73.32%
#  BankA_decision=denied: 25.83%
#  BankA_decision=error: 0.85%
#
# Goods_category: Mobile_devices
#  BankA_decision=success: 77.02%
#  BankA_decision=denied: 21.38%
#  BankA_decision=error: 1.60%
#
# Goods_category: Furniture
#  BankB_decision=success: 73.37%
#  BankB_decision=denied: 25.05%
#  BankB_decision=error: 1.58%
#
# Goods_category: Fitness
#  BankB_decision=success: 74.75%
#  BankB_decision=denied: 23.81%
#  BankB_decision=error: 1.43%
#
# Goods_category: Medical_services
#  BankB_decision=success: 76.09%
#  BankB_decision=denied: 23.15%
#  BankB_decision=error: 0.76%
#
# Goods_category: Education
#  BankB_decision=success: 75.03%
#  BankB_decision=denied: 24.10%
#  BankB_decision=error: 0.87%
#
# Goods_category: Other
#  BankB_decision=success: 70.30%
#  BankB_decision=denied: 28.35%
#  BankB_decision=error: 1.35%
#
# Goods_category: Travel
#  BankB_decision=success: 74.49%
#  BankB_decision=denied: 24.55%
#  BankB_decision=error: 0.96%
#
# Goods_category: Mobile_devices
#  BankB_decision=success: 75.74%
#  BankB_decision=denied: 23.09%
#  BankB_decision=error: 1.17%
#
# Goods_category: Furniture
#  BankC_decision=success: 73.79%
#  BankC_decision=denied: 24.95%
#  BankC_decision=error: 1.26%
#
# Goods_category: Fitness
#  BankC_decision=success: 77.29%
#  BankC_decision=denied: 22.49%
#  BankC_decision=error: 0.22%
#
# Goods_category: Medical_services
#  BankC_decision=success: 74.24%
#  BankC_decision=denied: 24.78%
#  BankC_decision=error: 0.98%
#
# Goods_category: Education
#  BankC_decision=success: 76.44%
#  BankC_decision=denied: 22.37%
#  BankC_decision=error: 1.19%
#
# Goods_category: Other
#  BankC_decision=success: 73.23%
#  BankC_decision=denied: 25.65%
#  BankC_decision=error: 1.12%
#
# Goods_category: Travel
#  BankC_decision=success: 74.28%
#  BankC_decision=denied: 24.87%
#  BankC_decision=error: 0.85%
#
# Goods_category: Mobile_devices
#  BankC_decision=success: 74.04%
#  BankC_decision=denied: 25.11%
#  BankC_decision=error: 0.85%
#
# Goods_category: Furniture
#  BankD_decision=success: 74.21%
#  BankD_decision=denied: 24.84%
#  BankD_decision=error: 0.95%
#
# Goods_category: Fitness
#  BankD_decision=success: 75.96%
#  BankD_decision=denied: 22.93%
#  BankD_decision=error: 1.10%
#
# Goods_category: Medical_services
#  BankD_decision=success: 73.70%
#  BankD_decision=denied: 25.43%
#  BankD_decision=error: 0.87%
#
# Goods_category: Education
#  BankD_decision=success: 75.14%
#  BankD_decision=denied: 23.34%
#  BankD_decision=error: 1.52%
#
# Goods_category: Other
#  BankD_decision=success: 75.37%
#  BankD_decision=denied: 23.06%
#  BankD_decision=error: 1.57%
#
# Goods_category: Travel
#  BankD_decision=success: 75.45%
#  BankD_decision=denied: 23.16%
#  BankD_decision=error: 1.39%
#
# Goods_category: Mobile_devices
#  BankD_decision=success: 74.57%
#  BankD_decision=denied: 24.68%
#  BankD_decision=error: 0.74%
#
# Goods_category: Furniture
#  BankE_decision=success: 75.26%
#  BankE_decision=denied: 23.37%
#  BankE_decision=error: 1.37%
#
# Goods_category: Fitness
#  BankE_decision=success: 77.18%
#  BankE_decision=denied: 21.72%
#  BankE_decision=error: 1.10%
#
# Goods_category: Medical_services
#  BankE_decision=success: 73.70%
#  BankE_decision=denied: 25.65%
#  BankE_decision=error: 0.65%
#
# Goods_category: Education
#  BankE_decision=success: 72.75%
#  BankE_decision=denied: 26.17%
#  BankE_decision=error: 1.09%
#
# Goods_category: Other
#  BankE_decision=success: 74.80%
#  BankE_decision=denied: 23.96%
#  BankE_decision=error: 1.24%
#
# Goods_category: Travel
#  BankE_decision=success: 77.69%
#  BankE_decision=denied: 21.02%
#  BankE_decision=error: 1.28%
#
# Goods_category: Mobile_devices
#  BankE_decision=success: 72.98%
#  BankE_decision=denied: 26.17%
#  BankE_decision=error: 0.85%

# %%
result_data = {'datasetElement': [], 'category': [], 'element_decision': [], 'percentage': []}

for datasetElement in dfColumns:
    categories = df[datasetElement].unique()
    for element in bank_list:
        for category in categories:
            subset = df[df[datasetElement] == category]
            bank_counts = subset[element].value_counts(normalize=True) * 100
            for decision, percentage in bank_counts.items():
                result_data['datasetElement'].append(datasetElement)
                result_data['category'].append(category)
                result_data['element_decision'].append(f"{element}={decision}")
                result_data['percentage'].append(percentage)

result_df = pd.DataFrame(result_data)

# %%
result_df
# Out:
#       datasetElement              category        element_decision  percentage
# 0          education   Высшее - специалист  BankA_decision=success   75.142640
# 1          education   Высшее - специалист   BankA_decision=denied   23.811335
# 2          education   Высшее - специалист    BankA_decision=error    1.046025
# 3          education  Неоконченное среднее  BankA_decision=success   76.923077
# 4          education  Неоконченное среднее   BankA_decision=denied   19.230769
# ...              ...                   ...                     ...         ...
# 3902  Goods_category                Travel   BankE_decision=denied   21.024546
# 3903  Goods_category                Travel    BankE_decision=error    1.280683
# 3904  Goods_category        Mobile_devices  BankE_decision=success   72.978723
# 3905  Goods_category        Mobile_devices   BankE_decision=denied   26.170213
# 3906  Goods_category        Mobile_devices    BankE_decision=error    0.851064
#
# [3907 rows x 4 columns]

# %% [markdown]
# #### 1.2.5 Выводы /пометки для датасета без пропусков

# %% [markdown]
# **SkillFactory_Id** в int
# **BirthDate** в age (если все события произошли хотя бы в течении полугода)
# education явно придётся категории объединять и сокращать название переменных
# **Value** возможно придётся объединять категории (перевод в числовую переменную с нормализацией?)
# **Position** может откинуть его?, у нас же есть уровень дохода, в любом случае на него нужно потратить много времени(устранения опечаток, слияние двух профессий написанных по разному(скоращения, женский и мужской вариант)) прежде чем мы сможем использовать столбец по назначению
# ****
#
# **MounthProfit и MonthExpense** требуют очистки от аномалий

# %% [markdown]
# 2. Поиск аномалий

# %% [markdown]
# ### датасет с пропущенными строками

# %%
df_drop.isna().sum()
# Out:
# SkillFactory_Id        0
# BirthDate              0
# education              0
# employment status      0
# Value                 80
# JobStartDate         109
# Position             109
# MonthProfit            0
# MonthExpense           0
# Gender                37
# Family status         37
# ChildCount            37
# SNILS                  0
# BankA_decision         0
# BankB_decision         0
# BankC_decision         0
# BankD_decision         0
# BankE_decision         0
# Merch_code             0
# Loan_amount            0
# Loan_term              0
# Goods_category         0
# dtype: int64

# %%
z = df_drop[(df_drop['JobStartDate'].isna() ==True) | df_drop['Gender'].isna() ==True]

# %%
z.isna().sum()
# Out:
# SkillFactory_Id        0
# BirthDate              0
# education              0
# employment status      0
# Value                 80
# JobStartDate         109
# Position             109
# MonthProfit            0
# MonthExpense           0
# Gender                37
# Family status         37
# ChildCount            37
# SNILS                  0
# BankA_decision         0
# BankB_decision         0
# BankC_decision         0
# BankD_decision         0
# BankE_decision         0
# Merch_code             0
# Loan_amount            0
# Loan_term              0
# Goods_category         0
# dtype: int64

# %%
bank_list = ['BankA_decision', 'BankB_decision', 'BankC_decision', 'BankD_decision', 'BankE_decision']

plt.figure(figsize=(7, 6))
plt.hist(z[bank_list])
plt.title('Распределение значений "решения банков"')
plt.show()#; строки с error отбрасываем? #МОЖНО СДЕЛАТЬ
